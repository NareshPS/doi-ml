# %% [markdown]
# # Parse model.fit() Output

# %%
grep "=====" test.log | cut -d' ' -f17 | awk 'BEGIN{printf("[")} {printf("%f,", $0)} END{print("]")}'

# %% [markdown]
# # Parse History

# %%
print(dict(map(lambda y: (y[0], list(map(lambda x: float('{:.6f}'.format(x)), y[1]))), history.items())))

# %% [markdown]
# # Plot Metrics

# %%
import numpy as np

from matplotlib import pyplot as plt

def plot(data, ax=None, style=None, label=None, mark='max'):
    def mark_fn():
        markx = np.argmax(data) if mark == 'max' else np.argmin(data)
        marky = max(data) if mark == 'max' else min(data)
        ax.scatter(markx, marky, zorder=2)


    ax = ax or plt.gca()
    style = style or '-'
    label = label or ''
    ax.plot(data, style, label=label)
    mark_fn() if mark else None

# %%
adam_conv = [0.009800,0.009800,0.024500,0.017600,0.031400,0.019600,0.022500,0.043100,0.045100,0.024500,0.045100,0.032400,0.050000,0.076500,0.052900,0.063700,0.060800,0.067600,0.101000,0.076500,0.074500,0.077500,0.101000,0.081400,0.051000,0.110800,0.069600,0.132400,0.148000,0.109800,0.156900,0.137300,0.110800,0.150000,0.118600,0.163700,0.183300,0.236300,0.203900,0.184300,0.169600,0.185300,0.119600,0.208800,0.198000,0.123500,0.202000,0.144100,0.092200,0.217600,0.246100,0.239200,0.244100,0.238200,0.216700,0.266700,0.250000,0.270600,0.269600,0.274500,0.257800,0.247100,0.261800,0.303900,0.291200,0.243100,0.300000,0.297100,0.280400,0.255900,0.257800,0.212700,0.302900,0.301000,0.248000,0.297100,0.298000,0.273500,0.262700,0.302000,0.284300,0.261800,0.276500,0.279400,0.282400,0.324500,0.324500,0.315700,0.300000,0.282400,0.346100,0.322500,0.364700,0.321600,0.311800,0.363700,0.339200,0.352900,0.341200,0.319600,0.344100,0.352900,0.309800,0.319600,0.355900,0.345100,0.310800,0.308800,0.317600,0.329400,0.242200,0.309800,0.334300,0.347100,0.352000,0.331400,0.361800,0.364700,0.369600,0.367600,0.361800,0.365700,0.374500,0.369600,0.355900,0.342200,0.341200,0.351000,0.354900,0.359800,0.372500,0.369600,0.325500,0.251000,0.340200,0.260800,0.229400,0.169600,0.199000,0.253900,0.304900,0.359800,0.388200,0.351000,0.332400,0.322500,0.361800,0.366700,0.274500,0.299000,0.273500,0.351000,0.379400,0.357800,0.344100,0.360800,0.400000,0.391200,0.370600,0.370600,0.402000,0.338200,0.395100,0.390200,0.378400,0.385300,0.381400,0.366700,0.369600,0.352900,0.334300,0.352900,0.354900,0.164700,0.114700,0.143100,0.145100,0.237300,0.267600,0.331400,0.325500,0.310800,0.365700,0.368600,0.391200,0.395100,0.402900,0.404900,0.348000,0.360800,0.386300,0.387300,0.388200,0.402900,0.402900,0.379400,0.389200,0.339200,0.305900,0.369600,0.378400,0.298000,0.263700,0.293100,0.302000,0.271600,0.286300,0.234300,0.287300,0.302000,0.337300,0.366700,0.360800,0.336300,0.316700,0.338200,0.313700,0.372500,0.370600,0.314700,0.309800,0.342200,0.
 0.241176, 0.164706, 0.194118, 0.190196, 0.201961, 0.203922, 0.192157, 0.201961, 0.211765, 0.245098, 0.232353, 0.248039, 0.279412, 0.246078, 0.230392, 0.266667, 0.246078, 0.252941, 0.242157, 0.211765, 0.245098, 0.194118, 0.217647, 0.223529, 0.238235, 0.246078, 0.248039, 0.240196, 0.248039, 0.227451, 0.196078, 0.223529, 0.240196, 0.208824, 0.194118, 0.160784, 0.227451, 0.127451, 0.228431, 0.25, 0.233333, 0.222549, 0.206863, 0.205882, 0.253922, 0.191176, 0.234314, 0.232353, 0.190196, 0.269608, 0.270588, 0.25, 0.216667, 0.234314, 0.143137, 0.202941, 0.235294, 0.248039, 0.240196, 0.251961, 0.277451, 0.263725, 0.269608, 0.235294, 0.204902, 0.215686, 0.208824, 0.216667, 0.155882, 0.141176, 0.251961, 0.270588, 0.22451, 0.246078, 0.288235, 0.203922, 0.25098, 0.255882, 0.158824, 0.169608, 0.236275, 0.270588, 0.240196, 0.22549, 0.235294, 0.255882, 0.259804, 0.210784, 0.260784]

plot(adam_conv, label='[conv] Adam')
plot(adadel_highlr_sic, label='[sic] AdaDelta LR 0.1')
plot(adadel_highlr_sidsc, label='[sidsc] AdaDelta LR 0.1')
plot(adadel_highlr_sidsc, label='[sicsc] AdaDelta LR 0.1')
# plot(adadel_highlr_sicwc_squeeze, label='[sicwc][squeeze] AdaDelta LR 0.1')
# plot(nadm_sicpc_squeeze, label='[sicpc][squeeze] Nadam')
plot(nadm_sicwc_squeeze, label='[sicwc][squeeze] Nadam')

axes = plt.gca()
axes.set_xlabel('Epoch')
axes.set_ylabel('Accuracy')
axes.set_title('Comparison of Convolution Layers')


axes.legend()
plt.show()

# %%
import tensorflow as tf

scores = [0.01683364, 0.02314224, 0.01643265, 0.01896303, 0.0370173 ,
       0.01553664, 0.01117901, 0.01904086, 0.01551224, 0.01027294,
       0.01754347, 0.01482745, 0.01072181, 0.02153939, 0.01743654,
       0.01658158, 0.01486312, 0.01386998, 0.01486312, 0.01363553,
       0.01482745, 0.01486312, 0.01486312, 0.01445088, 0.01655908,
       0.01551224, 0.01486312, 0.01399966, 0.01486312, 0.0166438 ,
       0.01486312, 0.01486312, 0.01496924, 0.01496924, 0.01496924,
       0.01496924, 0.01496924, 0.01496924, 0.01496924, 0.01496924,
       0.01496924, 0.01496924, 0.01496924, 0.01496924, 0.01496924,
       0.01496924, 0.01496924, 0.01496924, 0.01496924, 0.01496924,
       0.01496924, 0.01496924, 0.01496924, 0.01496924, 0.01496924,
       0.01496924, 0.01496924, 0.01496924, 0.01496924, 0.01496924,
       0.01496924, 0.01496924, 0.01496924, 0.01496924]

sum(scores)

m = tf.random.uniform((3, 3))
sm = tf.nn.softmax(m)
tf.print(m, sm)
tf.reduce_sum(sm[0]), tf.reduce_sum(sm[1]), tf.reduce_sum(sm[2]), tf.reduce_sum(sm[..., 0]), tf.reduce_sum(sm[..., 1]), tf.reduce_sum(sm[..., 2])
# Out:
# [[0.971494913 0.0354096889 0.399646401]
#  [0.210314393 0.977287412 0.803667307]
#  [0.253461123 0.158849597 0.56502974]] [[0.511079967 0.200425148 0.288494945]
#  [0.20147942 0.433833271 0.364687264]
#  [0.305316299 0.277754247 0.416929394]]
# (<tf.Tensor: shape=(), dtype=float32, numpy=1.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.99999994>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.9999999>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=1.0178757>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.91201264>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=1.0701116>)

# %%
import tensorflow_datasets as tfds

train_ds, info = tfds.load('mnist', split='train', with_info=True)
itr = iter(train_ds)

# %%
from PIL import Image

im = Image.new("RGB", (500, 500), 'white')
d = aggdraw.Draw(im)
p = aggdraw.Pen("black", 0.5)
d.line((0, 0, 500, 500), p)
d.line((0, 500, 500, 0), p)
d.flush()
im.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7839/202818758.py in <module>
#       2
#       3 im = Image.new("RGB", (500, 500), 'white')
# ----> 4 d = aggdraw.Draw(im)
#       5 p = aggdraw.Pen("black", 0.5)
#       6 d.line((0, 0, 500, 500), p)
#
# NameError: name 'aggdraw' is not defined

# %%
import cv2
import numpy as np

from urllib.request import urlopen
from matplotlib import pyplot as plt

image_path = 'https://farm1.staticflickr.com/4141/4780447561_3959bc024b_o.jpg'
IMG_SIZE = 256

def loadImage(url):
  with urlopen(url) as request:
      img_array = np.asarray(bytearray(request.read()), dtype=np.uint8)

  img = cv2.imdecode(img_array, cv2.IMREAD_COLOR)
  img = cv2.resize(img, (IMG_SIZE, IMG_SIZE), cv2.INTER_AREA)
  return cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(int)
# Out:
# float64

# %%
def rotate_image(image, angle, center=(np.random.randint(0, IMG_SIZE), np.random.randint(0, IMG_SIZE))):
  rot_mat = cv2.getRotationMatrix2D(center=center, angle=angle, scale=1)

#   image = np.random.uniform((200, 200, 3))
  image = image.astype(np.float32)
  result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
  return result.astype(int)

r_image = rotate_image(image, 10)
c_image = rotate_image(image, 10, (127, 127))

fig, axes = plt.subplots(1, 3, facecolor='w')
axes[0].imshow(image)
axes[1].imshow(r_image)
axes[2].imshow(c_image)

# %%
# import tensorflow as tf
# import tensorflow.keras.layers as layers
# import matplotlib.pyplot as plt
# import tensorflow_datasets as tfds

# train_ds, = tfds.load('wider_face', split=['train[39:]'])
# itr = iter(train_ds)
# item = next(itr)

image = item['image']

IMG_SIZE = 256
MAX_INPUT_BOXES = 2
MAX_BOXES = 5

def yx_to_indices(yx, size, dtype=tf.int64):
    return tf.cast(yx*(size - 1), dtype)

def yxyx_to_cycxhw_grid(boxes, grid_size):
    """
        It converts a tensor of YXYX boxes into a grid of HW values.
        HW values are inserted based on CYCX values into the grid.

        boxes: A tensor of boxes. Shape: (N_BOXES, 4). The last dimension
            contains YXYX values.
        grid_size: The size of the grid to insert HW values.

        Returns:
            A grid with HW values. Shape: (grid_size, grid_size, 2)
    """
    # Compute box CYCX and HW.
    cy, cx = (boxes[:, 0] + boxes[:, 2])/2, (boxes[:, 1] + boxes[:, 3])/2
    cycx, hw = tf.stack([cy, cx], axis=-1), boxes[:, 2:] - boxes[:, :2]

    # Find the grid indices corresponding to the box centers.
    indices = yx_to_indices(cycx, grid_size, dtype=tf.int32)
    
    # tf.print('indices: ', indices, indices.shape)

    # Construct the grid based on the center indices and HW values
    grid = tf.scatter_nd(indices=indices, updates=hw, shape=(grid_size, grid_size, 2))

    # tf.print('grid: ', grid, grid.shape)

    return grid

def resize_fn(bboxes, current_shape, target_size=IMG_SIZE):
    # Resize ratios
    H, W = current_shape
    ratio_H, ratio_W = target_size/H, target_size/W
    bboxes = bboxes*[ratio_H, ratio_W, ratio_H, ratio_W]

    return bboxes
    # return bboxes.astype('float32')

def preprocess_as_center_grid(item):
    image, boxes = item['image'], item['faces']['bbox']
    # tf.print('boxes: ', boxes, boxes.shape)

    # Resize image to IMG_SIZE
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.cast(image, tf.float32) / 255.0

    # Transform YXYX boxes to CYCX
    resized_boxes = resize_fn(boxes, image.shape[:-1], IMG_SIZE)[:MAX_INPUT_BOXES-1]
    resized_boxes.set_shape([None, 4])

    # Map CYCXHW coordinates to a grid of size IMG_SIZE
    grid = yxyx_to_cycxhw_grid(resized_boxes, IMG_SIZE)

    # tf.print('cycx_boxes: ', cycx_boxes, cycx_boxes.shape)
    # tf.print('grid: ', grid, grid.shape)

    return image, grid

@tf.function
def filter_empty_bboxes(item):
    _, bboxes = item['image'], item['faces']['bbox']

    return tf.shape(bboxes)[0] != 0

train_prep_ds = train_ds.filter(filter_empty_bboxes).map(preprocess_as_center_grid, num_parallel_calls=None)
itr = iter(train_prep_ds.batch(1))
image, y_true = next(itr)

plt.imshow(image[0])

# %%
def plot_box_centers(ax, boxes, size, color='green', alpha=1.0, marker_size=None):
    """
        ax: Plot Axes.
        boxes: A tensor of CYCXHW values for the box centers. Shape: (N_BOXES, 4)
        size: Size of the image. It is used to translate the CYCX values to image size.
        color: A string to indicate the color in matplotlib format for the bounding boxes.
        alpha: A FP value for the box fill.
    """
    if boxes is None: return

    boxes = boxes*size
    y, x = boxes[:, 0], boxes[:, 1]

    ax.scatter(x, y, color=color, s=marker_size, alpha=alpha)

    for box_id, yi in enumerate(y):
        xi = x[box_id]
        ax.text(xi, yi, str(box_id + 1), ha='center', va='center', size='xx-small', color='white')

def hw_grid_to_yxhw(grid):
    """
        It translates a square HW grid to a list of boxes. Only the boxes with non-zero heights
        are qualified.

        Arguments:
            grid: A grid of of shape: (SIZE, SIZE, 2) with HW values in the last dimension.
        
        Returns:
            A tensor of shape (N_BOXES, 4). The last dimension contains YXHW values.
    """
    # Grid size
    size = grid.shape[0]

    # Generate valid box indices. We consider the boxes with non-zero heights as valid boxes
    mask = tf.cast(tf.math.not_equal(grid[:, :, 0], 0.), tf.float32)
    indices = tf.where(mask)

    # Compute YX and HW for valid boxes
    yx = tf.cast(indices/size, dtype=tf.float32)
    hw = tf.gather_nd(indices=indices, params=grid)

    # tf.print('indices: ', indices, indices.shape)
    # tf.print('first grid element', grid[indices[0][0], indices[0][1]])
    # tf.print('last grid element', grid[indices[-1][0], indices[-1][1]])

    yxhw = tf.concat([yx, hw], axis=-1)

    return yxhw

def plot_in_out(axes, in_img=None, in_boxes=None, out_img=None, out_boxes=None, size=IMG_SIZE):
    # _, [in_ax, out_ax] = plt.subplots(2, figsize=(6, 12))
    [in_ax, out_ax] = axes

    if in_img is not None: in_ax.imshow(in_img[0])
    if in_boxes is not None: plot_box_centers(in_ax, in_boxes, size)
    if out_img is not None: out_ax.imshow(out_img[0])

# boxes = hw_grid_to_yxhw(y_true[0])

patch_size = IMG_SIZE//2
top_left = image[:, :patch_size, :patch_size]
top_right = image[:, :patch_size, patch_size:]
bottom_left = image[:, patch_size:, :patch_size]
bottom_right = image[:, patch_size:, patch_size:]
num_patches = 4

tl_box_grid = y_true[:, :patch_size, :patch_size, :]
tr_box_grid = y_true[:, :patch_size, patch_size:, :]
bl_box_grid = y_true[:, patch_size:, :patch_size, :]
br_box_grid = y_true[:, patch_size:, patch_size:, :]

tl_boxes = hw_grid_to_yxhw(tl_box_grid[0])
tr_boxes = hw_grid_to_yxhw(tr_box_grid[0])
bl_boxes = hw_grid_to_yxhw(bl_box_grid[0])
br_boxes = hw_grid_to_yxhw(br_box_grid[0])

# _, [tl_ax, tr_ax, bl_ax, br_ax] = plt.subplots(4, figsize=(4, 16))
_, [tl_ax, tr_ax, bl_ax, br_ax] = plt.subplots(4, 2, figsize=(6, 12))

plot_in_out(tl_ax, top_left, tl_boxes, size=IMG_SIZE//2)
plot_in_out(tr_ax, top_right, tr_boxes, size=IMG_SIZE//2)
plot_in_out(bl_ax, bottom_left, bl_boxes, size=IMG_SIZE//2)
plot_in_out(br_ax, bottom_right, br_boxes, size=IMG_SIZE//2)

# %%
import matplotlib.pyplot as plt

def create_model():
    inp = tf.keras.Input((patch_size, patch_size, 3))
    convs = tf.keras.Sequential([
        layers.Conv2D(1, 3),
        layers.MaxPool2D(),
        layers.Conv2D(1, 3),
        layers.MaxPool2D(),
        layers.Conv2D(1, 3),
        layers.MaxPool2D(),
    ])(inp)

    y = layers.Reshape((convs.shape[1], -1))(convs)
    x = layers.Permute((2, 1, 3))(convs)
    x = layers.Reshape((convs.shape[2], -1))(x)
    yx_scores = layers.Attention()([y, x])
    
    model = tf.keras.Model(inputs=inp, outputs=yx_scores)

    return model

model = create_model()

EPOCHS = 2

# for epoch in range(EPOCHS):


def train(patch):
    with tf.GradientTape() as tape:
        output = model(patch, training=True)
    
    return output

tl_output = train(top_left)

tl_output.shape
# _, [tl_ax, tr_ax, bl_ax, br_ax] = plt.subplots(4, 2, figsize=(6, 12))
# plot_in_out(tl_ax, top_left, hw_grid_to_yxhw(tl_box_grid[0]), tl_output, size=IMG_SIZE//2)
# plot_in_out(tr_ax, top_right, hw_grid_to_yxhw(tr_box_grid[0]), size=IMG_SIZE//2)
# Out:
# TensorShape([1, 14, 14])
