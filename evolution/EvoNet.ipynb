# %% [markdown]
# ## Issues
# - [Resolved](https://github.com/NareshPS/doi-ml/issues/3) Split cell visualization per config. Add accuracy info to the visuals.
# - [Invalid](https://github.com/NareshPS/doi-ml/issues/4) Investigate duplicate accuracies in the population.
# - [Resolved](https://github.com/NareshPS/doi-ml/issues/6) Center merge strategy to merge two parents.
# - [Resolved](https://github.com/NareshPS/doi-ml/issues/9) Refactor: Simplify search space definitions and references.
# - [Resolved](https://github.com/NareshPS/doi-ml/issues/12) Multilevel Cells.
# - [Open](https://github.com/NareshPS/doi-ml/issues/8) Stitch single block from second parent.

# %% [markdown]
# ## Installation

# %%
# ! pip install -q git+https://github.com/EfficientDL/codelab_utils.git

# %%
import random
import seaborn
import numpy.typing
import traceback

import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import pandas as pd
import codelab_utils.mpl_styles as mpl_styles
import networkx as nx

from tensorflow.keras import layers, losses, models, optimizers
from matplotlib import pyplot as plt
from matplotlib import ticker
from collections import deque
from random import sample, shuffle, randrange
from math import floor
from functools import reduce
from typing import List, Tuple

SEED = 111

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

mpl_styles.set_default_styles()
plt.rcParams['font.family'] = 'Poppins'

# %%
# %%capture

DATASET_PARAMS = dict(
    input_shape=(32, 32, 3),
    n_classes=10,
    baseline_accuracy=.1,
    train_batch_size=128
)

train_ds, val_ds = tfds.load(
    'cifar10',
    split=['train[:80%]', 'train[20%:]'],
    as_supervised=True
)
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2022-12-13 16:52:08.238300: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-12-13 16:52:08.238558: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# %%capture --no-display

def display(display_list, cols=2, size=(8, 8)):
    rows = (len(display_list) + cols - 1)//cols
    fig, axes = plt.subplots(rows, cols, figsize=size)

    def get_axis(index):
        row, col = index//cols, index%cols
        return axes[row, col] if rows>1 else axes[col]
    
    for index, item in enumerate(display_list):
        image, label = item
        axis = get_axis(index)
        axis.imshow(tf.keras.utils.array_to_img(image))
        axis.set_xlabel(label)

items = []
for item in train_ds.take(2).as_numpy_iterator():
    items.append(item)

display(items, size=(2,2))
# Out:
# 2022-12-13 16:52:10.567143: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-12-13 16:52:10.600264: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# ## Configuration

# %%
CHILD_PARAMS = dict(
    epochs=1,
    batch_size=DATASET_PARAMS['train_batch_size'],
    learning_rate=0.001,
    train_ds=train_ds,
    val_ds=val_ds,
    max_branch_length=2,
    blocks=11,
    cells=2,
    # layers is a list of pairs of cell type and stride.
    # Normal cells have single stride. Reduction cells have two strides.
    # layers=[(0, 4), (1, 64), (0, 128), (1, 512), (0, 1024)],
    layers=[(0, 8), (1, 16), (0, 32), (1, 64), (0, 128)],

)

CONTROLLER_PARAMS = dict(
    episodes=2,
    population_size=8,
    sample_size=4,
    max_mutations=2,
    # mutation_strategy='mixed', # it should not be used for multilevel cells
    mutation_strategy='point',
    merge_strategy='center_merge',
    parent_selection_strategy='top_two',
)

# %% [markdown]
# ## Support Classes

# %%
class NumpyOps(object):
    def with_indices(self, a):
        rows, cols = a.shape
        row_indices = np.array(list(range(rows))).reshape((rows, 1))
        col_indices = np.array([0] + list(range(cols))).reshape((1, cols+1))

        result = np.concatenate([row_indices, a], axis=1)
        result = np.concatenate([col_indices, result], axis=0)
        return result

class RandomOps(object):
    def choice(self, s):
        return random.choice(s)
    
    def choice_with_index(self, s):
        s_id = random.choice(range(len(s)))
        element = s[s_id]
        return s_id, element

random_ops = RandomOps()
numpy_ops = NumpyOps()

# %% [markdown]
# ## Search Space

# %%
class StateSearchSpace(object):
    def __init__(self, name='state', choices=[], size=2, labels=[]) -> None:
        self.name = name
        self.choices = choices or list(range(size))
        self.labels = labels or self.choices
    
    def __str__(self) -> str:
        return '{}: {}'.format(
            self.name,
            self.labels
        )
    
    def __len__(self) -> int:
        return len(self.choices)
    
    def __getitem__(self, address):
        return self.choices[address]
    
    def random(self):
        return random_ops.choice(self.choices)
    
    def random_element(self, level):
        state = random_ops.choice(self.choices)
        return state
    
    def decode(self, state):
        index = self.choices.index(state)
        return self.labels[index]
    
class BlockSearchSpace(object):
    def __init__(self) -> None:
        self.elements = []
    
    def add_state(self, kwargs):
        state = StateSearchSpace(**kwargs)
        self.elements.append(state)

        return state
    
    def __str__(self) -> str:
        desc = 'States\n======\n'
        desc += '\n'.join(map(str, self.elements))
        return desc
    
    def __len__(self) -> int:
        return len(self.elements)
    
    def __getitem__(self, address):
        return self.elements[address]
    
    def random(self) -> np.typing.NDArray[int]:
        return np.array(list(
            map(lambda s: s.random(), self.elements)
        ))
    
    def random_element(self, level):
        s_id, elem = random_ops.choice_with_index(self.elements)

        if level == 0:
            address, elem = (s_id,), elem
        else:
            elem = elem.random_element(level-1)
            address = (s_id,)

        return address, elem
    
    def decode(self, block):
        return np.array(list(map(
            lambda p: p[1].decode(block[p[0]]),
            enumerate(self.elements)
        )))
        

class CellSearchSpace(object):
    def __init__(self, block_search_space, blocks=1) -> None:
        self.block_search_space = block_search_space
        self.blocks = blocks
        self.cell_search_space = np.array(list(
            map(
                lambda _: list(map(lambda s: s.name, block_search_space.elements)),
                range(blocks)
            )
        ))
    
    def __str__(self) -> str:
        return str(self.cell_search_space)
    
    def __len__(self) -> int:
        return self.cell_search_space.size
    
    def __getitem__(self, address):
        return self.cell_search_space[address]

    def random(self):
        return np.array(list(
            map(
                lambda _: self.block_search_space.random(),
                range(self.blocks)
            )
        ))

class TwoLevelCellSearchSpace(object):
    def __init__(self, child_params) -> None:
        self.child_params = child_params
        self.input_labels = ['input 0', 'input 1']
        self.block_labels = list(map(
            lambda b_id: 'block {}'.format(b_id),
            range(self.child_params['blocks'])
        ))

        # State Descriptions
        self.primitives = dict(
            name='primitives',
            size=6,
            labels=['sep_3x3', 'sep_5x5', 'sep_7x7', 'avg_3x3', 'max_3x3', 'identity']
        )
        self.combinations = dict(
            name='combinations',
            size=2,
            labels=['add', 'concat']
        )

        # Block Search Spaces
        self.blocks = self.create_search_space()
        self.cell_search_space_names = np.array(list(map(
            lambda b: list(map(lambda s: s.name, b.elements)),
            self.blocks
        )))
    
    def create_search_space(self):
        return self.create_first_level() + self.create_second_level()
    
    def create_first_level(self):
        block_count = self.child_params['blocks']//2
        inputs = dict(name='inputs', size=2, labels=self.input_labels)

        def create_block(_):
            block = BlockSearchSpace()
            states = list(map(
                block.add_state,
                [
                    inputs,
                    inputs,
                    self.primitives,
                    self.primitives,
                    self.combinations
                ]
            ))
            return block

        return list(map(
            create_block,
            range(block_count)
        ))
    
    def create_second_level(self):
        level_1_block_count = self.child_params['blocks']//2
        level_2_block_count = self.child_params['blocks'] - level_1_block_count
    
        # Second level input labels
        left_input_labels = self.input_labels + self.block_labels[:level_1_block_count]
        right_input_labels = self.block_labels[:level_1_block_count]

        # Second level input states
        left_inputs = dict(
            name='mixed',
            size=len(left_input_labels),
            labels=left_input_labels
        )
        right_inputs = dict(
            name='blocks',
            # size=len(right_input_labels),
            choices=list(range(len(self.input_labels), len(left_input_labels))),
            labels=right_input_labels
        )

        def create_block(_):
            block = BlockSearchSpace()
            states = list(map(
                block.add_state,
                [
                    left_inputs,
                    right_inputs,
                    self.primitives,
                    self.primitives,
                    self.combinations
                ]
            ))
            return block

        return list(map(
            create_block,
            range(level_2_block_count)
        ))
    
    def __str__(self) -> str:
        return np.array2string(self.cell_search_space_names)
    
    def __len__(self) -> int:
        return len(self.blocks)
    
    def size(self) -> int:
        return self.cell_search_space_names.size
    
    def describe(self) -> np.typing.NDArray[str]:
        return self.cell_search_space_names
    
    @property
    def shape(self) -> Tuple[int]:
        return self.cell_search_space_names.shape
    
    def __getitem__(self, address):
        return self.blocks[address]
    
    def random(self):
        return np.array(list(
            map(
                lambda b: b.random(),
                self.blocks
            )
        ))
    
    def random_element(self, level, desc=False):
        b_id, block = random_ops.choice_with_index(self.blocks)

        if level == 0:
            address, elem = (b_id,), block
        else:
            interm_address, elem = block.random_element(level-1)
            address = (b_id,) + interm_address

        result = (address, elem)

        if desc:
            status = np.empty_like(self.cell_search_space_names)
            status[address] = elem if type(elem) is int else 'X'
            result += (status,)

        return result
    
    def decode(self, config):
        return np.array(list(map(
            lambda p: p[1].decode(config[p[0]]),
            enumerate(self.blocks)
        )))


# state = state_space.random()
# state, state_space.decode(state)

# block_space = BlockSearchSpace()
# block_space.add_state(dict(labels=['input 0', 'input 1']))
# block_space.add_state(dict(size=3, labels=['block 0', 'block 1', 'block 2']))
# block_config = block_space.random()
# block_config, block_space.decode(block_config)

search_space = TwoLevelCellSearchSpace(CHILD_PARAMS)
# cell_config = search_space.random()
# print(cell_config)
# search_space.decode(cell_config)

# print(numpy_ops.with_indices(cell_config))
# numpy_ops.with_indices(cell_config)

# %% [markdown]
# ## Evolution Strategies

# %%
class ParentSelectionStrategies(object):
    def __init__(self) -> None:
        self.elementary_strategies = [
            'best',
            'best_and_random',
            'top_two',
        ]
        self.strategies = {
            'best': self.best,
            'best_and_random': self.best_and_random,
            'top_two': self.top_two,
        }
    
    def best_and_random(self, num_candidates):
        best_parent = num_candidates - 1
        random_parent = random.randrange(num_candidates-1)

        return [best_parent, random_parent]
    
    def top_two(self, num_candidates):
        return [num_candidates-1, num_candidates-2]
    
    def best(self, num_candidates):
        best_parent = num_candidates - 1
        return [best_parent, best_parent]
    
    def get(self, name='best_and_random'):
        return self.strategies[name]

class MutationStrategies(object):
    def __init__(self, search_space) -> None:
        # self.child_params = child_params
        self.search_space = search_space
        self.elementary_strategies = ['point', 'block_swap']
        self.strategies = {
            'point': self.point,
            'block_swap': self.block_swap,
            'mixed': self.mixed,
            'gene_shuffle': self.gene_shuffle,
        }
    
    def point(self, config):
        address, value, desc = self.search_space.random_element(2, desc=True)

        old_config = config.copy()
        config[address] = value

        print('Point Mutation\n===============\n', address, value)
        print(desc)
        print(config == old_config)

        return config
    
    def block_swap(self, config):
        coordinates = list(map(
            randrange, [len(self.search_space)]*2
            # randrange, [self.child_params['blocks']]*2
        ))
        old_config = config.copy()
        config[coordinates] = config[list(reversed(coordinates))]
        print('Block Swap\n===============\n', coordinates)
        print(config == old_config)

        return config
    
    def mixed(self, config):
        strategy_id = randrange(len(self.elementary_strategies))
        
        return self.strategies[self.elementary_strategies[strategy_id]](config)
    
    def gene_shuffle(self, config):
        block_indices = list(range(config.shape[0]))
        random.shuffle(block_indices)

        # Select Genes
        selected = config[block_indices[:len(self.search_space)]]
        print('Gene Shuffle\n============\n', block_indices[:len(self.search_space)])
        return selected

    def get(self, name='point'):
        return self.strategies[name]

class MergeStrategies(object):
    def __init__(self, search_space, mix_strategy) -> None:
        self.elementary_strategies = [
            'pick_first',
            'mix_two',
            'center_merge'
        ]
        self.strategies = {
            'pick_first': self.pick_first,
            'mix_two': self.mix_two,
            'center_merge': self.center_merge
        }
        self.mix_strategy = mix_strategy
        self.search_space = search_space
    
    def pick_first(self, *parents):
        return parents[0]

    def mix_two(self, *parents):
        first, second = parents
        return np.array(list(
            map(
                lambda c: self.mix_strategy(np.concatenate(c)),
                zip(first, second)
            )
        ))
    
    def center_merge(self, *parents):
        first, second = parents
        left_merge_point = len(self.search_space)//2
        right_merge_point = (len(self.search_space)+1)//2
        merge_point = random.choice([left_merge_point, right_merge_point])

        return np.array(list(
            map(
                lambda c: np.concatenate([c[0][:merge_point], c[1][merge_point:]]),
                zip(first, second)
            )
        ))

    def get(self, name='pick_first'):
        return self.strategies[name]

mutation_strategies = MutationStrategies(search_space)
merge_strategies = MergeStrategies(
    search_space,
    mutation_strategies.get('gene_shuffle')
)

# cell_config = search_space.random()
# mutation_strategies.point(cell_config)
# search_space.random_element(1, desc=True)
# mutation_strategies.point(cell_config)
# mutation_strategies.block_swap(cell_config)
# mutation_strategies.mixed(cell_config)
# mutation_strategies.gene_shuffle(cell_config)
# config_1 = random_child_config(CHILD_PARAMS, search_space)
# config_2 = random_child_config(CHILD_PARAMS, search_space)
# merged = merge_strategies.center_merge(config_1, config_2)
# merged = merge_strategies.pick_first(config_1, config_2)
# merged = merge_strategies.mix_two(config_1, config_2)
# config_1 == merged, config_2 == merged

# %% [markdown]
# ## Cell Block
#
# * Support to reduce channels
# * Debug

# %%
class CellBlock(layers.Layer):
    """
    It composes a cell based on the input configuration.
    Arguments:
        channels: Number of output channels
    """
    def __init__(self, config, channels=64, cell_type=0):
        super().__init__(name='cell_block')
        
        self.channels = channels
        self.config = config
        self.cell_type = cell_type
    
    def apply_op(self, op_id, inp):
        """
        It applies a primitive operation to the input.
        """
        kwargs = dict(strides=(1, 1), padding='same')
        if op_id == 0:
            output = layers.DepthwiseConv2D(3, **kwargs)(inp)
        elif op_id == 1:
            output = layers.DepthwiseConv2D(5, **kwargs)(inp)
        elif op_id == 2:
            output = layers.DepthwiseConv2D(7, **kwargs)(inp)
        elif op_id == 3:
            output = layers.AveragePooling2D(3, **kwargs)(inp)
        elif op_id == 4:
            output = layers.MaxPool2D(3, **kwargs)(inp)
        elif op_id == 5:
            output = inp
        
        return output

    def combination(self, op_id, inp_1, inp_2):
        """
        It applies a combination operation to the inputs.
        """
        if op_id == 0:
            output = inp_1 + inp_2
        elif op_id == 1:
            x = tf.concat([inp_1, inp_2], -1)
            output = self.repair_channels(x)
        
        return output

    def compose_block(self, block_config, inputs):
        input_0, input_1 = list(map(inputs.__getitem__, block_config[:2]))
        op1, op2, combine_op = block_config[2:]
        # print(block_config)

        output = self.combination(
            combine_op,
            self.apply_op(op1, input_0),
            self.apply_op(op2, input_1)
        )

        return output
    
    def repair(self, x, strides=[]):
        """
        Stacks conv layers according to strides over the input 'x'.
        """
        return reduce(
            lambda y,stride: layers.Conv2D(
                self.channels,
                3,
                strides=(stride, stride),
                padding='same'
            )(y),
            strides,
            x
        )
    
    def repair_inputs(self, inputs):
        """
        It transforms the inputs to an identical feature space.
        It is useful when a cell receives inputs with different feature spaces.
        
        We reduce by a factor of 2 in each step. For an incoming input with 4x
        the feature space of the last layer, we stack 2 conv layers
        to achieve the desired reduction.
        """
        input_feature_size = inputs[-1].shape[-2]
        reductions = list(map(
            lambda x: [2]*(x.shape[-2]//input_feature_size-1),
            inputs
        ))
        return list(map(
            lambda p: self.repair_channels(self.repair(p[0], p[1])),
            zip(inputs, reductions)
        ))
    
    def repair_channels(self, x):
        """
        This method sends the input through a convolution layer with
        a fixed channel size to ensure that the inputs to each cell block
        have identical channel dimensions.
        """
        if x.shape[-1] != self.channels:
            x = layers.Conv2D(self.channels, 1, padding='same')(x)

        return x

    def is_reduction_cell(self):
        return self.cell_type == 1
    
    def call(self, inputs):
        """
        It constructs a cell based on the cell_config and the inputs.
        A cell_config is 2-D numpy array of shape [N,5] which contains
        the 5 state choices for each cell block.
        """
        # Reduce inputs, if requested.
        last_input = inputs[-1]
        inputs.append(self.repair(last_input, [2]) if self.is_reduction_cell() else last_input)

        inputs = self.repair_inputs(inputs)
        # print(inputs)

        blocks = []
        for b_id, block in enumerate(self.config):
            block_output = self.compose_block(block, inputs + blocks)
            blocks.append(block_output)
        
        x = tf.concat(blocks, -1)
        x = self.repair_channels(x)
        return x

def create_child(config):
    inp = tf.keras.Input(shape=DATASET_PARAMS['input_shape'], dtype=tf.uint8)
    x = layers.Rescaling(1./255)(inp)

    branches = deque([x, x], maxlen=CHILD_PARAMS['max_branch_length'])
    for cell_type, channels in CHILD_PARAMS['layers']:
        cnn_cell = CellBlock(config[cell_type], channels=channels, cell_type=cell_type)
        x = cnn_cell.call(list(branches))
        
        branches.append(x)
    
    model = tf.keras.Model(inp, x)
    optimizer = optimizers.Adam()

    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics='accuracy'
    )

    return model

config = np.array([search_space.random(), search_space.random()])
# for cc in config: print(search_space.decode(cc))
m = create_child(config)
m.summary()
# tf.keras.utils.plot_model(m)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  rescaling_14 (Rescaling)       (None, 32, 32, 3)    0           ['input_15[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 32, 32, 8)    32          ['rescaling_14[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 32, 32, 8)    32          ['rescaling_14[0][0]']
#
#  depthwise_conv2d_278 (Depthwis  (None, 32, 32, 8)   80          ['conv2d_243[0][0]']
#  eConv2D)
#
#  max_pooling2d_92 (MaxPooling2D  (None, 32, 32, 8)   0           ['conv2d_243[0][0]']
#  )
#
#  max_pooling2d_93 (MaxPooling2D  (None, 32, 32, 8)   0           ['conv2d_243[0][0]']
#  )
#
#  depthwise_conv2d_280 (Depthwis  (None, 32, 32, 8)   208         ['conv2d_244[0][0]']
#  eConv2D)
#
#  tf.concat_162 (TFOpLambda)     (None, 32, 32, 16)   0           ['depthwise_conv2d_278[0][0]',
#                                                                   'max_pooling2d_92[0][0]']
#
#  depthwise_conv2d_279 (Depthwis  (None, 32, 32, 8)   208         ['conv2d_243[0][0]']
#  eConv2D)
#
#  average_pooling2d_75 (AverageP  (None, 32, 32, 8)   0           ['conv2d_244[0][0]']
#  ooling2D)
#
#  tf.concat_164 (TFOpLambda)     (None, 32, 32, 16)   0           ['max_pooling2d_93[0][0]',
#                                                                   'depthwise_conv2d_280[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 32, 32, 8)    136         ['tf.concat_162[0][0]']
#
#  tf.concat_163 (TFOpLambda)     (None, 32, 32, 16)   0           ['depthwise_conv2d_279[0][0]',
#                                                                   'average_pooling2d_75[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 32, 32, 8)    136         ['tf.concat_164[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 32, 32, 8)    32          ['rescaling_14[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 32, 32, 8)    136         ['tf.concat_163[0][0]']
#
#  depthwise_conv2d_281 (Depthwis  (None, 32, 32, 8)   80          ['conv2d_244[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_282 (Depthwis  (None, 32, 32, 8)   400         ['conv2d_245[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_284 (Depthwis  (None, 32, 32, 8)   80          ['conv2d_243[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_285 (Depthwis  (None, 32, 32, 8)   400         ['conv2d_246[0][0]']
#  eConv2D)
#
#  average_pooling2d_78 (AverageP  (None, 32, 32, 8)   0           ['conv2d_248[0][0]']
#  ooling2D)
#
#  depthwise_conv2d_277 (Depthwis  (None, 32, 32, 8)   80          ['conv2d_243[0][0]']
#  eConv2D)
#
#  average_pooling2d_74 (AverageP  (None, 32, 32, 8)   0           ['conv2d_243[0][0]']
#  ooling2D)
#
#  tf.concat_165 (TFOpLambda)     (None, 32, 32, 16)   0           ['conv2d_243[0][0]',
#                                                                   'conv2d_244[0][0]']
#
#  tf.concat_166 (TFOpLambda)     (None, 32, 32, 16)   0           ['depthwise_conv2d_281[0][0]',
#                                                                   'depthwise_conv2d_282[0][0]']
#
#  depthwise_conv2d_283 (Depthwis  (None, 32, 32, 8)   80          ['conv2d_248[0][0]']
#  eConv2D)
#
#  average_pooling2d_76 (AverageP  (None, 32, 32, 8)   0           ['conv2d_245[0][0]']
#  ooling2D)
#
#  tf.concat_167 (TFOpLambda)     (None, 32, 32, 16)   0           ['depthwise_conv2d_284[0][0]',
#                                                                   'depthwise_conv2d_285[0][0]']
#
#  max_pooling2d_94 (MaxPooling2D  (None, 32, 32, 8)   0           ['conv2d_248[0][0]']
#  )
#
#  average_pooling2d_77 (AverageP  (None, 32, 32, 8)   0           ['conv2d_246[0][0]']
#  ooling2D)
#
#  depthwise_conv2d_286 (Depthwis  (None, 32, 32, 8)   208         ['conv2d_244[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_287 (Depthwis  (None, 32, 32, 8)   208         ['conv2d_245[0][0]']
#  eConv2D)
#
#  tf.concat_168 (TFOpLambda)     (None, 32, 32, 16)   0           ['conv2d_247[0][0]',
#                                                                   'average_pooling2d_78[0][0]']
#
#  tf.__operators__.add_138 (TFOp  (None, 32, 32, 8)   0           ['depthwise_conv2d_277[0][0]',
#  Lambda)                                                          'average_pooling2d_74[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 32, 32, 8)    136         ['tf.concat_165[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 32, 32, 8)    136         ['tf.concat_166[0][0]']
#
#  tf.__operators__.add_139 (TFOp  (None, 32, 32, 8)   0           ['depthwise_conv2d_283[0][0]',
#  Lambda)                                                          'average_pooling2d_76[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 32, 32, 8)    136         ['tf.concat_167[0][0]']
#
#  tf.__operators__.add_140 (TFOp  (None, 32, 32, 8)   0           ['max_pooling2d_94[0][0]',
#  Lambda)                                                          'average_pooling2d_77[0][0]']
#
#  tf.__operators__.add_141 (TFOp  (None, 32, 32, 8)   0           ['depthwise_conv2d_286[0][0]',
#  Lambda)                                                          'depthwise_conv2d_287[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 32, 32, 8)    136         ['tf.concat_168[0][0]']
#
#  tf.concat_169 (TFOpLambda)     (None, 32, 32, 88)   0           ['tf.__operators__.add_138[0][0]'
#                                                                  , 'conv2d_246[0][0]',
#                                                                   'conv2d_247[0][0]',
#                                                                   'conv2d_248[0][0]',
#                                                                   'conv2d_249[0][0]',
#                                                                   'conv2d_250[0][0]',
#                                                                   'tf.__operators__.add_139[0][0]'
#                                                                  , 'conv2d_251[0][0]',
#                                                                   'tf.__operators__.add_140[0][0]'
#                                                                  , 'tf.__operators__.add_141[0][0]
#                                                                  ',
#                                                                   'conv2d_252[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 32, 32, 8)    712         ['tf.concat_169[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 16, 16, 16)   1168        ['conv2d_253[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 16, 16, 16)   448         ['rescaling_14[0][0]']
#
#  average_pooling2d_79 (AverageP  (None, 16, 16, 16)  0           ['conv2d_256[0][0]']
#  ooling2D)
#
#  max_pooling2d_95 (MaxPooling2D  (None, 16, 16, 16)  0           ['conv2d_256[0][0]']
#  )
#
#  depthwise_conv2d_288 (Depthwis  (None, 16, 16, 16)  160         ['conv2d_256[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_289 (Depthwis  (None, 16, 16, 16)  800         ['conv2d_256[0][0]']
#  eConv2D)
#
#  tf.concat_171 (TFOpLambda)     (None, 16, 16, 32)   0           ['conv2d_255[0][0]',
#                                                                   'average_pooling2d_79[0][0]']
#
#  depthwise_conv2d_290 (Depthwis  (None, 16, 16, 16)  800         ['conv2d_256[0][0]']
#  eConv2D)
#
#  max_pooling2d_96 (MaxPooling2D  (None, 16, 16, 16)  0           ['conv2d_256[0][0]']
#  )
#
#  tf.__operators__.add_142 (TFOp  (None, 16, 16, 16)  0           ['max_pooling2d_95[0][0]',
#  Lambda)                                                          'conv2d_256[0][0]']
#
#  tf.concat_170 (TFOpLambda)     (None, 16, 16, 32)   0           ['depthwise_conv2d_288[0][0]',
#                                                                   'depthwise_conv2d_289[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 16, 16, 16)   528         ['tf.concat_171[0][0]']
#
#  tf.__operators__.add_143 (TFOp  (None, 16, 16, 16)  0           ['depthwise_conv2d_290[0][0]',
#  Lambda)                                                          'max_pooling2d_96[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 16, 16, 16)   1168        ['conv2d_253[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 16, 16, 16)   528         ['tf.concat_170[0][0]']
#
#  max_pooling2d_99 (MaxPooling2D  (None, 16, 16, 16)  0           ['conv2d_254[0][0]']
#  )
#
#  max_pooling2d_100 (MaxPooling2  (None, 16, 16, 16)  0           ['conv2d_254[0][0]']
#  D)
#
#  depthwise_conv2d_293 (Depthwis  (None, 16, 16, 16)  416         ['tf.__operators__.add_143[0][0]'
#  eConv2D)                                                        ]
#
#  average_pooling2d_80 (AverageP  (None, 16, 16, 16)  0           ['conv2d_258[0][0]']
#  ooling2D)
#
#  depthwise_conv2d_294 (Depthwis  (None, 16, 16, 16)  416         ['tf.__operators__.add_143[0][0]'
#  eConv2D)                                                        ]
#
#  max_pooling2d_101 (MaxPooling2  (None, 16, 16, 16)  0           ['tf.__operators__.add_142[0][0]'
#  D)                                                              ]
#
#  max_pooling2d_97 (MaxPooling2D  (None, 16, 16, 16)  0           ['conv2d_256[0][0]']
#  )
#
#  max_pooling2d_98 (MaxPooling2D  (None, 16, 16, 16)  0           ['conv2d_256[0][0]']
#  )
#
#  tf.concat_172 (TFOpLambda)     (None, 16, 16, 32)   0           ['max_pooling2d_99[0][0]',
#                                                                   'max_pooling2d_100[0][0]']
#
#  depthwise_conv2d_291 (Depthwis  (None, 16, 16, 16)  416         ['conv2d_256[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_292 (Depthwis  (None, 16, 16, 16)  416         ['tf.__operators__.add_143[0][0]'
#  eConv2D)                                                        ]
#
#  tf.concat_173 (TFOpLambda)     (None, 16, 16, 32)   0           ['depthwise_conv2d_293[0][0]',
#                                                                   'average_pooling2d_80[0][0]']
#
#  tf.concat_174 (TFOpLambda)     (None, 16, 16, 32)   0           ['depthwise_conv2d_294[0][0]',
#                                                                   'max_pooling2d_101[0][0]']
#
#  depthwise_conv2d_295 (Depthwis  (None, 16, 16, 16)  416         ['conv2d_254[0][0]']
#  eConv2D)
#
#  max_pooling2d_102 (MaxPooling2  (None, 16, 16, 16)  0           ['conv2d_258[0][0]']
#  D)
#
#  depthwise_conv2d_296 (Depthwis  (None, 16, 16, 16)  416         ['conv2d_255[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_297 (Depthwis  (None, 16, 16, 16)  416         ['conv2d_257[0][0]']
#  eConv2D)
#
#  tf.__operators__.add_144 (TFOp  (None, 16, 16, 16)  0           ['max_pooling2d_97[0][0]',
#  Lambda)                                                          'max_pooling2d_98[0][0]']
#
#  conv2d_259 (Conv2D)            (None, 16, 16, 16)   528         ['tf.concat_172[0][0]']
#
#  tf.__operators__.add_145 (TFOp  (None, 16, 16, 16)  0           ['depthwise_conv2d_291[0][0]',
#  Lambda)                                                          'depthwise_conv2d_292[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 16, 16, 16)   528         ['tf.concat_173[0][0]']
#
#  conv2d_261 (Conv2D)            (None, 16, 16, 16)   528         ['tf.concat_174[0][0]']
#
#  tf.__operators__.add_146 (TFOp  (None, 16, 16, 16)  0           ['depthwise_conv2d_295[0][0]',
#  Lambda)                                                          'max_pooling2d_102[0][0]']
#
#  tf.__operators__.add_147 (TFOp  (None, 16, 16, 16)  0           ['depthwise_conv2d_296[0][0]',
#  Lambda)                                                          'depthwise_conv2d_297[0][0]']
#
#  tf.concat_175 (TFOpLambda)     (None, 16, 16, 176)  0           ['tf.__operators__.add_142[0][0]'
#                                                                  , 'conv2d_257[0][0]',
#                                                                   'conv2d_258[0][0]',
#                                                                   'tf.__operators__.add_143[0][0]'
#                                                                  , 'tf.__operators__.add_144[0][0]
#                                                                  ',
#                                                                   'conv2d_259[0][0]',
#                                                                   'tf.__operators__.add_145[0][0]'
#                                                                  , 'conv2d_260[0][0]',
#                                                                   'conv2d_261[0][0]',
#                                                                   'tf.__operators__.add_146[0][0]'
#                                                                  , 'tf.__operators__.add_147[0][0]
#                                                                  ']
#
#  conv2d_262 (Conv2D)            (None, 16, 16, 16)   2832        ['tf.concat_175[0][0]']
#
#  conv2d_263 (Conv2D)            (None, 16, 16, 32)   2336        ['conv2d_253[0][0]']
#
#  conv2d_264 (Conv2D)            (None, 16, 16, 32)   544         ['conv2d_262[0][0]']
#
#  depthwise_conv2d_299 (Depthwis  (None, 16, 16, 32)  320         ['conv2d_263[0][0]']
#  eConv2D)
#
#  max_pooling2d_103 (MaxPooling2  (None, 16, 16, 32)  0           ['conv2d_263[0][0]']
#  D)
#
#  max_pooling2d_104 (MaxPooling2  (None, 16, 16, 32)  0           ['conv2d_263[0][0]']
#  D)
#
#  depthwise_conv2d_301 (Depthwis  (None, 16, 16, 32)  832         ['conv2d_264[0][0]']
#  eConv2D)
#
#  tf.concat_176 (TFOpLambda)     (None, 16, 16, 64)   0           ['depthwise_conv2d_299[0][0]',
#                                                                   'max_pooling2d_103[0][0]']
#
#  depthwise_conv2d_300 (Depthwis  (None, 16, 16, 32)  832         ['conv2d_263[0][0]']
#  eConv2D)
#
#  average_pooling2d_82 (AverageP  (None, 16, 16, 32)  0           ['conv2d_264[0][0]']
#  ooling2D)
#
#  tf.concat_178 (TFOpLambda)     (None, 16, 16, 64)   0           ['max_pooling2d_104[0][0]',
#                                                                   'depthwise_conv2d_301[0][0]']
#
#  conv2d_266 (Conv2D)            (None, 16, 16, 32)   2080        ['tf.concat_176[0][0]']
#
#  tf.concat_177 (TFOpLambda)     (None, 16, 16, 64)   0           ['depthwise_conv2d_300[0][0]',
#                                                                   'average_pooling2d_82[0][0]']
#
#  conv2d_268 (Conv2D)            (None, 16, 16, 32)   2080        ['tf.concat_178[0][0]']
#
#  conv2d_265 (Conv2D)            (None, 16, 16, 32)   544         ['conv2d_262[0][0]']
#
#  conv2d_267 (Conv2D)            (None, 16, 16, 32)   2080        ['tf.concat_177[0][0]']
#
#  depthwise_conv2d_302 (Depthwis  (None, 16, 16, 32)  320         ['conv2d_264[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_303 (Depthwis  (None, 16, 16, 32)  1600        ['conv2d_265[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_305 (Depthwis  (None, 16, 16, 32)  320         ['conv2d_263[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_306 (Depthwis  (None, 16, 16, 32)  1600        ['conv2d_266[0][0]']
#  eConv2D)
#
#  average_pooling2d_85 (AverageP  (None, 16, 16, 32)  0           ['conv2d_268[0][0]']
#  ooling2D)
#
#  depthwise_conv2d_298 (Depthwis  (None, 16, 16, 32)  320         ['conv2d_263[0][0]']
#  eConv2D)
#
#  average_pooling2d_81 (AverageP  (None, 16, 16, 32)  0           ['conv2d_263[0][0]']
#  ooling2D)
#
#  tf.concat_179 (TFOpLambda)     (None, 16, 16, 64)   0           ['conv2d_263[0][0]',
#                                                                   'conv2d_264[0][0]']
#
#  tf.concat_180 (TFOpLambda)     (None, 16, 16, 64)   0           ['depthwise_conv2d_302[0][0]',
#                                                                   'depthwise_conv2d_303[0][0]']
#
#  depthwise_conv2d_304 (Depthwis  (None, 16, 16, 32)  320         ['conv2d_268[0][0]']
#  eConv2D)
#
#  average_pooling2d_83 (AverageP  (None, 16, 16, 32)  0           ['conv2d_265[0][0]']
#  ooling2D)
#
#  tf.concat_181 (TFOpLambda)     (None, 16, 16, 64)   0           ['depthwise_conv2d_305[0][0]',
#                                                                   'depthwise_conv2d_306[0][0]']
#
#  max_pooling2d_105 (MaxPooling2  (None, 16, 16, 32)  0           ['conv2d_268[0][0]']
#  D)
#
#  average_pooling2d_84 (AverageP  (None, 16, 16, 32)  0           ['conv2d_266[0][0]']
#  ooling2D)
#
#  depthwise_conv2d_307 (Depthwis  (None, 16, 16, 32)  832         ['conv2d_264[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_308 (Depthwis  (None, 16, 16, 32)  832         ['conv2d_265[0][0]']
#  eConv2D)
#
#  tf.concat_182 (TFOpLambda)     (None, 16, 16, 64)   0           ['conv2d_267[0][0]',
#                                                                   'average_pooling2d_85[0][0]']
#
#  tf.__operators__.add_148 (TFOp  (None, 16, 16, 32)  0           ['depthwise_conv2d_298[0][0]',
#  Lambda)                                                          'average_pooling2d_81[0][0]']
#
#  conv2d_269 (Conv2D)            (None, 16, 16, 32)   2080        ['tf.concat_179[0][0]']
#
#  conv2d_270 (Conv2D)            (None, 16, 16, 32)   2080        ['tf.concat_180[0][0]']
#
#  tf.__operators__.add_149 (TFOp  (None, 16, 16, 32)  0           ['depthwise_conv2d_304[0][0]',
#  Lambda)                                                          'average_pooling2d_83[0][0]']
#
#  conv2d_271 (Conv2D)            (None, 16, 16, 32)   2080        ['tf.concat_181[0][0]']
#
#  tf.__operators__.add_150 (TFOp  (None, 16, 16, 32)  0           ['max_pooling2d_105[0][0]',
#  Lambda)                                                          'average_pooling2d_84[0][0]']
#
#  tf.__operators__.add_151 (TFOp  (None, 16, 16, 32)  0           ['depthwise_conv2d_307[0][0]',
#  Lambda)                                                          'depthwise_conv2d_308[0][0]']
#
#  conv2d_272 (Conv2D)            (None, 16, 16, 32)   2080        ['tf.concat_182[0][0]']
#
#  tf.concat_183 (TFOpLambda)     (None, 16, 16, 352)  0           ['tf.__operators__.add_148[0][0]'
#                                                                  , 'conv2d_266[0][0]',
#                                                                   'conv2d_267[0][0]',
#                                                                   'conv2d_268[0][0]',
#                                                                   'conv2d_269[0][0]',
#                                                                   'conv2d_270[0][0]',
#                                                                   'tf.__operators__.add_149[0][0]'
#                                                                  , 'conv2d_271[0][0]',
#                                                                   'tf.__operators__.add_150[0][0]'
#                                                                  , 'tf.__operators__.add_151[0][0]
#                                                                  ',
#                                                                   'conv2d_272[0][0]']
#
#  conv2d_273 (Conv2D)            (None, 16, 16, 32)   11296       ['tf.concat_183[0][0]']
#
#  conv2d_276 (Conv2D)            (None, 8, 8, 64)     18496       ['conv2d_273[0][0]']
#
#  conv2d_275 (Conv2D)            (None, 8, 8, 64)     9280        ['conv2d_262[0][0]']
#
#  average_pooling2d_86 (AverageP  (None, 8, 8, 64)    0           ['conv2d_276[0][0]']
#  ooling2D)
#
#  max_pooling2d_106 (MaxPooling2  (None, 8, 8, 64)    0           ['conv2d_276[0][0]']
#  D)
#
#  depthwise_conv2d_309 (Depthwis  (None, 8, 8, 64)    640         ['conv2d_276[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_310 (Depthwis  (None, 8, 8, 64)    3200        ['conv2d_276[0][0]']
#  eConv2D)
#
#  tf.concat_185 (TFOpLambda)     (None, 8, 8, 128)    0           ['conv2d_275[0][0]',
#                                                                   'average_pooling2d_86[0][0]']
#
#  depthwise_conv2d_311 (Depthwis  (None, 8, 8, 64)    3200        ['conv2d_276[0][0]']
#  eConv2D)
#
#  max_pooling2d_107 (MaxPooling2  (None, 8, 8, 64)    0           ['conv2d_276[0][0]']
#  D)
#
#  tf.__operators__.add_152 (TFOp  (None, 8, 8, 64)    0           ['max_pooling2d_106[0][0]',
#  Lambda)                                                          'conv2d_276[0][0]']
#
#  tf.concat_184 (TFOpLambda)     (None, 8, 8, 128)    0           ['depthwise_conv2d_309[0][0]',
#                                                                   'depthwise_conv2d_310[0][0]']
#
#  conv2d_278 (Conv2D)            (None, 8, 8, 64)     8256        ['tf.concat_185[0][0]']
#
#  tf.__operators__.add_153 (TFOp  (None, 8, 8, 64)    0           ['depthwise_conv2d_311[0][0]',
#  Lambda)                                                          'max_pooling2d_107[0][0]']
#
#  conv2d_274 (Conv2D)            (None, 8, 8, 64)     18496       ['conv2d_273[0][0]']
#
#  conv2d_277 (Conv2D)            (None, 8, 8, 64)     8256        ['tf.concat_184[0][0]']
#
#  max_pooling2d_110 (MaxPooling2  (None, 8, 8, 64)    0           ['conv2d_274[0][0]']
#  D)
#
#  max_pooling2d_111 (MaxPooling2  (None, 8, 8, 64)    0           ['conv2d_274[0][0]']
#  D)
#
#  depthwise_conv2d_314 (Depthwis  (None, 8, 8, 64)    1664        ['tf.__operators__.add_153[0][0]'
#  eConv2D)                                                        ]
#
#  average_pooling2d_87 (AverageP  (None, 8, 8, 64)    0           ['conv2d_278[0][0]']
#  ooling2D)
#
#  depthwise_conv2d_315 (Depthwis  (None, 8, 8, 64)    1664        ['tf.__operators__.add_153[0][0]'
#  eConv2D)                                                        ]
#
#  max_pooling2d_112 (MaxPooling2  (None, 8, 8, 64)    0           ['tf.__operators__.add_152[0][0]'
#  D)                                                              ]
#
#  max_pooling2d_108 (MaxPooling2  (None, 8, 8, 64)    0           ['conv2d_276[0][0]']
#  D)
#
#  max_pooling2d_109 (MaxPooling2  (None, 8, 8, 64)    0           ['conv2d_276[0][0]']
#  D)
#
#  tf.concat_186 (TFOpLambda)     (None, 8, 8, 128)    0           ['max_pooling2d_110[0][0]',
#                                                                   'max_pooling2d_111[0][0]']
#
#  depthwise_conv2d_312 (Depthwis  (None, 8, 8, 64)    1664        ['conv2d_276[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_313 (Depthwis  (None, 8, 8, 64)    1664        ['tf.__operators__.add_153[0][0]'
#  eConv2D)                                                        ]
#
#  tf.concat_187 (TFOpLambda)     (None, 8, 8, 128)    0           ['depthwise_conv2d_314[0][0]',
#                                                                   'average_pooling2d_87[0][0]']
#
#  tf.concat_188 (TFOpLambda)     (None, 8, 8, 128)    0           ['depthwise_conv2d_315[0][0]',
#                                                                   'max_pooling2d_112[0][0]']
#
#  depthwise_conv2d_316 (Depthwis  (None, 8, 8, 64)    1664        ['conv2d_274[0][0]']
#  eConv2D)
#
#  max_pooling2d_113 (MaxPooling2  (None, 8, 8, 64)    0           ['conv2d_278[0][0]']
#  D)
#
#  depthwise_conv2d_317 (Depthwis  (None, 8, 8, 64)    1664        ['conv2d_275[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_318 (Depthwis  (None, 8, 8, 64)    1664        ['conv2d_277[0][0]']
#  eConv2D)
#
#  tf.__operators__.add_154 (TFOp  (None, 8, 8, 64)    0           ['max_pooling2d_108[0][0]',
#  Lambda)                                                          'max_pooling2d_109[0][0]']
#
#  conv2d_279 (Conv2D)            (None, 8, 8, 64)     8256        ['tf.concat_186[0][0]']
#
#  tf.__operators__.add_155 (TFOp  (None, 8, 8, 64)    0           ['depthwise_conv2d_312[0][0]',
#  Lambda)                                                          'depthwise_conv2d_313[0][0]']
#
#  conv2d_280 (Conv2D)            (None, 8, 8, 64)     8256        ['tf.concat_187[0][0]']
#
#  conv2d_281 (Conv2D)            (None, 8, 8, 64)     8256        ['tf.concat_188[0][0]']
#
#  tf.__operators__.add_156 (TFOp  (None, 8, 8, 64)    0           ['depthwise_conv2d_316[0][0]',
#  Lambda)                                                          'max_pooling2d_113[0][0]']
#
#  tf.__operators__.add_157 (TFOp  (None, 8, 8, 64)    0           ['depthwise_conv2d_317[0][0]',
#  Lambda)                                                          'depthwise_conv2d_318[0][0]']
#
#  tf.concat_189 (TFOpLambda)     (None, 8, 8, 704)    0           ['tf.__operators__.add_152[0][0]'
#                                                                  , 'conv2d_277[0][0]',
#                                                                   'conv2d_278[0][0]',
#                                                                   'tf.__operators__.add_153[0][0]'
#                                                                  , 'tf.__operators__.add_154[0][0]
#                                                                  ',
#                                                                   'conv2d_279[0][0]',
#                                                                   'tf.__operators__.add_155[0][0]'
#                                                                  , 'conv2d_280[0][0]',
#                                                                   'conv2d_281[0][0]',
#                                                                   'tf.__operators__.add_156[0][0]'
#                                                                  , 'tf.__operators__.add_157[0][0]
#                                                                  ']
#
#  conv2d_282 (Conv2D)            (None, 8, 8, 64)     45120       ['tf.concat_189[0][0]']
#
#  conv2d_283 (Conv2D)            (None, 8, 8, 128)    36992       ['conv2d_273[0][0]']
#
#  conv2d_284 (Conv2D)            (None, 8, 8, 128)    8320        ['conv2d_282[0][0]']
#
#  depthwise_conv2d_320 (Depthwis  (None, 8, 8, 128)   1280        ['conv2d_283[0][0]']
#  eConv2D)
#
#  max_pooling2d_114 (MaxPooling2  (None, 8, 8, 128)   0           ['conv2d_283[0][0]']
#  D)
#
#  max_pooling2d_115 (MaxPooling2  (None, 8, 8, 128)   0           ['conv2d_283[0][0]']
#  D)
#
#  depthwise_conv2d_322 (Depthwis  (None, 8, 8, 128)   3328        ['conv2d_284[0][0]']
#  eConv2D)
#
#  tf.concat_190 (TFOpLambda)     (None, 8, 8, 256)    0           ['depthwise_conv2d_320[0][0]',
#                                                                   'max_pooling2d_114[0][0]']
#
#  depthwise_conv2d_321 (Depthwis  (None, 8, 8, 128)   3328        ['conv2d_283[0][0]']
#  eConv2D)
#
#  average_pooling2d_89 (AverageP  (None, 8, 8, 128)   0           ['conv2d_284[0][0]']
#  ooling2D)
#
#  tf.concat_192 (TFOpLambda)     (None, 8, 8, 256)    0           ['max_pooling2d_115[0][0]',
#                                                                   'depthwise_conv2d_322[0][0]']
#
#  conv2d_286 (Conv2D)            (None, 8, 8, 128)    32896       ['tf.concat_190[0][0]']
#
#  tf.concat_191 (TFOpLambda)     (None, 8, 8, 256)    0           ['depthwise_conv2d_321[0][0]',
#                                                                   'average_pooling2d_89[0][0]']
#
#  conv2d_288 (Conv2D)            (None, 8, 8, 128)    32896       ['tf.concat_192[0][0]']
#
#  conv2d_285 (Conv2D)            (None, 8, 8, 128)    8320        ['conv2d_282[0][0]']
#
#  conv2d_287 (Conv2D)            (None, 8, 8, 128)    32896       ['tf.concat_191[0][0]']
#
#  depthwise_conv2d_323 (Depthwis  (None, 8, 8, 128)   1280        ['conv2d_284[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_324 (Depthwis  (None, 8, 8, 128)   6400        ['conv2d_285[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_326 (Depthwis  (None, 8, 8, 128)   1280        ['conv2d_283[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_327 (Depthwis  (None, 8, 8, 128)   6400        ['conv2d_286[0][0]']
#  eConv2D)
#
#  average_pooling2d_92 (AverageP  (None, 8, 8, 128)   0           ['conv2d_288[0][0]']
#  ooling2D)
#
#  depthwise_conv2d_319 (Depthwis  (None, 8, 8, 128)   1280        ['conv2d_283[0][0]']
#  eConv2D)
#
#  average_pooling2d_88 (AverageP  (None, 8, 8, 128)   0           ['conv2d_283[0][0]']
#  ooling2D)
#
#  tf.concat_193 (TFOpLambda)     (None, 8, 8, 256)    0           ['conv2d_283[0][0]',
#                                                                   'conv2d_284[0][0]']
#
#  tf.concat_194 (TFOpLambda)     (None, 8, 8, 256)    0           ['depthwise_conv2d_323[0][0]',
#                                                                   'depthwise_conv2d_324[0][0]']
#
#  depthwise_conv2d_325 (Depthwis  (None, 8, 8, 128)   1280        ['conv2d_288[0][0]']
#  eConv2D)
#
#  average_pooling2d_90 (AverageP  (None, 8, 8, 128)   0           ['conv2d_285[0][0]']
#  ooling2D)
#
#  tf.concat_195 (TFOpLambda)     (None, 8, 8, 256)    0           ['depthwise_conv2d_326[0][0]',
#                                                                   'depthwise_conv2d_327[0][0]']
#
#  max_pooling2d_116 (MaxPooling2  (None, 8, 8, 128)   0           ['conv2d_288[0][0]']
#  D)
#
#  average_pooling2d_91 (AverageP  (None, 8, 8, 128)   0           ['conv2d_286[0][0]']
#  ooling2D)
#
#  depthwise_conv2d_328 (Depthwis  (None, 8, 8, 128)   3328        ['conv2d_284[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_329 (Depthwis  (None, 8, 8, 128)   3328        ['conv2d_285[0][0]']
#  eConv2D)
#
#  tf.concat_196 (TFOpLambda)     (None, 8, 8, 256)    0           ['conv2d_287[0][0]',
#                                                                   'average_pooling2d_92[0][0]']
#
#  tf.__operators__.add_158 (TFOp  (None, 8, 8, 128)   0           ['depthwise_conv2d_319[0][0]',
#  Lambda)                                                          'average_pooling2d_88[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 8, 8, 128)    32896       ['tf.concat_193[0][0]']
#
#  conv2d_290 (Conv2D)            (None, 8, 8, 128)    32896       ['tf.concat_194[0][0]']
#
#  tf.__operators__.add_159 (TFOp  (None, 8, 8, 128)   0           ['depthwise_conv2d_325[0][0]',
#  Lambda)                                                          'average_pooling2d_90[0][0]']
#
#  conv2d_291 (Conv2D)            (None, 8, 8, 128)    32896       ['tf.concat_195[0][0]']
#
#  tf.__operators__.add_160 (TFOp  (None, 8, 8, 128)   0           ['max_pooling2d_116[0][0]',
#  Lambda)                                                          'average_pooling2d_91[0][0]']
#
#  tf.__operators__.add_161 (TFOp  (None, 8, 8, 128)   0           ['depthwise_conv2d_328[0][0]',
#  Lambda)                                                          'depthwise_conv2d_329[0][0]']
#
#  conv2d_292 (Conv2D)            (None, 8, 8, 128)    32896       ['tf.concat_196[0][0]']
#
#  tf.concat_197 (TFOpLambda)     (None, 8, 8, 1408)   0           ['tf.__operators__.add_158[0][0]'
#                                                                  , 'conv2d_286[0][0]',
#                                                                   'conv2d_287[0][0]',
#                                                                   'conv2d_288[0][0]',
#                                                                   'conv2d_289[0][0]',
#                                                                   'conv2d_290[0][0]',
#                                                                   'tf.__operators__.add_159[0][0]'
#                                                                  , 'conv2d_291[0][0]',
#                                                                   'tf.__operators__.add_160[0][0]'
#                                                                  , 'tf.__operators__.add_161[0][0]
#                                                                  ',
#                                                                   'conv2d_292[0][0]']
#
#  conv2d_293 (Conv2D)            (None, 8, 8, 128)    180352      ['tf.concat_197[0][0]']
#
# ==================================================================================================
# Total params: 702,256
# Trainable params: 702,256
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## UnitBlock

# %%
# class UnitBlock(layers.Layer):
#     def __init__(self, blocks=2) -> None:
#         super().__init__()
#         self.blocks = blocks
    
#     def call(self, inputs):

class Cursor(object):
    def __init__(self, value=0) -> None:
        self.value = value

    def increment(self):
        self.value += 1
    
    def get(self):
        return self.value

class UnitBlock(layers.Layer):
    def __init__(self, config, params) -> None:
        super().__init__(name='unit_block')
        self.config = config
        self.params = params
    
    def call(self, inputs):
        x = inputs
        branches = deque([x, x], maxlen=self.params['max_branch_length'])

        for cell_type, channels in self.params['layers']:
            x = CellBlock(
                self.config[cell_type],
                channels=channels,
                cell_type=cell_type
            )(list(branches))
            
            branches.append(x)
        
        return x

def make_unit_block(config):
    inp = tf.keras.Input(shape=DATASET_PARAMS['input_shape'], dtype=tf.uint8)
    x = layers.Rescaling(1./255)(inp)
    x = UnitBlock(config, CHILD_PARAMS)(x)

    x = layers.GlobalAveragePooling2D()(x)
    output = layers.Dense(DATASET_PARAMS['n_classes'], activation='softmax')(x)

    model = tf.keras.Model(inp, output)
    optimizer = optimizers.Adam(learning_rate=CHILD_PARAMS['learning_rate'])

    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics='accuracy'
    )

    return model

config = search_space.random()
model = make_unit_block(config)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# StagingError                              Traceback (most recent call last)
# Cell In [33], line 59
#      56     return model
#      58 config = search_space.random()
# ---> 59 model = make_unit_block(config)
#      60 model.summary()
#
# Cell In [33], line 42, in make_unit_block(config)
#      40 inp = tf.keras.Input(shape=DATASET_PARAMS['input_shape'], dtype=tf.uint8)
#      41 x = layers.Rescaling(1./255)(inp)
# ---> 42 x = UnitBlock(config, CHILD_PARAMS)(x)
#      44 x = layers.GlobalAveragePooling2D()(x)
#      45 output = layers.Dense(DATASET_PARAMS['n_classes'], activation='softmax')(x)
#
# File ~/miniforge3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniforge3/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:692, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
# --> 692     raise e.ag_error_metadata.to_exception(e)
#     693   else:
#     694     raise
#
# StagingError: Exception encountered when calling layer "unit_block" (type UnitBlock).
#
# in user code:
#
#     File "/var/folders/8y/5694n0_n42j4fmg6d5j411480000gn/T/ipykernel_67426/3143232872.py", line 29, in call  *
#         x = CellBlock(
#     File "/Users/broxoli/miniforge3/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#
#     StagingError: Exception encountered when calling layer "cell_block" "                 f"(type CellBlock).
#
#     in user code:
#
#         File "/var/folders/8y/5694n0_n42j4fmg6d5j411480000gn/T/ipykernel_67426/4217120624.py", line 121, in call  *
#             block_output = self.compose_block(block, inputs + blocks)
#         File "/var/folders/8y/5694n0_n42j4fmg6d5j411480000gn/T/ipykernel_67426/4217120624.py", line 46, in compose_block  *
#             input_0, input_1 = list(map(inputs.__getitem__, block_config[:2]))
#
#         IndexError: invalid index to scalar variable.
#
#
#     Call arguments received by layer "cell_block" "                 f"(type CellBlock):
#       • inputs=['tf.Tensor(shape=(None, 32, 32, 3), dtype=float32)', 'tf.Tensor(shape=(None, 32, 32, 3), dtype=float32)', 'tf.Tensor(shape=(None, 32, 32, 3), dtype=float32)']
#
#
# Call arguments received by layer "unit_block" (type UnitBlock):
#   • inputs=tf.Tensor(shape=(None, 32, 32, 3), dtype=float32)

# %% [markdown]
# ## Child Architecture

# %%
TDS = CHILD_PARAMS['train_ds'].shuffle(
    500,
    reshuffle_each_iteration=True
).batch(CHILD_PARAMS['batch_size']).take(2)
VDS = CHILD_PARAMS['val_ds'].batch(256).take(2)

class Child(object):
    def __init__(self, config, params, train=True):
        self.config = config
        self.params = params

        """
        Layer configuration is a pair: (layer_type, stride)
        A normal layer take a single stride and a reduction layer
        take a double stride.
        """
        # self.layers = [(0, 1), (1, 2), (0, 1), (1, 2), (0, 1)]
        self.model = self.make_child()
        self.accuracy = 0.0
        self.accuracy = self.train() if train else 0
        print('Child: {} \n Accuracy: {:1.4f}'.format(
            self.config,
            self.accuracy
        ))
    
    def make_child(self):
        """
        Arguments:
            config: It is an array of shape [2, 5, 5]
                    Each row represents a cell: [Normal, Reduction]
                    Each cell contains 5 blocks.
                    Each block contains 5 operations.

        Returns:
            model: A CNN model with the layers laid out based on the input config.
        """
        inp = tf.keras.Input(shape=DATASET_PARAMS['input_shape'], dtype=tf.uint8)
        x = layers.Rescaling(1./255)(inp)

        branches = deque([x, x], maxlen=self.params['max_branch_length'])
        
        for cell_type, channels in self.params['layers']:
            cnn_cell = CellBlock(channels)
            x = cnn_cell.make_cell(self.config[cell_type], list(branches), apply_reduction=bool(cell_type))
            
            branches.append(x)

        x = layers.GlobalAveragePooling2D()(x)
        output = layers.Dense(DATASET_PARAMS['n_classes'], activation='softmax')(x)

        model = tf.keras.Model(inp, output)
        optimizer = optimizers.Adam(learning_rate=self.params['learning_rate'])

        model.compile(
            optimizer=optimizer,
            loss='sparse_categorical_crossentropy',
            metrics='accuracy'
        )
        # model.summary()

        return model

    def train(self):
        history = self.model.fit(
            TDS,
            validation_data=VDS,
            epochs=self.params['epochs']
        )
        self.accuracy = max(history.history['val_accuracy'])

        return self.accuracy

# config = np.array(list(map(lambda _: search_space.random(), range(2))))
# for cc in config: print(search_space.decode(cc))
# child = Child(config, CHILD_PARAMS, train=False)
# tf.keras.utils.plot_model(child.model, show_shapes=True)
# child.model.summary()
# Out:
# Child: [[[0 1 3 1 1]
#   [1 2 5 1 1]
#   [2 2 1 5 1]]
#
#  [[1 1 5 2 1]
#   [0 2 3 0 1]
#   [2 2 4 3 1]]]
#  Accuracy: 0.0000
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  rescaling_1 (Rescaling)        (None, 32, 32, 3)    0           ['input_2[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 4)    16          ['rescaling_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 4)    16          ['rescaling_1[0][0]']
#
#  average_pooling2d (AveragePool  (None, 32, 32, 4)   0           ['conv2d[0][0]']
#  ing2D)
#
#  depthwise_conv2d (DepthwiseCon  (None, 32, 32, 4)   104         ['conv2d_1[0][0]']
#  v2D)
#
#  tf.concat (TFOpLambda)         (None, 32, 32, 8)    0           ['average_pooling2d[0][0]',
#                                                                   'depthwise_conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 4)    36          ['tf.concat[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 32, 32, 4)   104         ['conv2d_2[0][0]']
#  onv2D)
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 32, 32, 4)   104         ['conv2d_2[0][0]']
#  onv2D)
#
#  tf.concat_1 (TFOpLambda)       (None, 32, 32, 8)    0           ['conv2d_1[0][0]',
#                                                                   'depthwise_conv2d_1[0][0]']
#
#  tf.concat_2 (TFOpLambda)       (None, 32, 32, 8)    0           ['depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 4)    36          ['tf.concat_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 4)    36          ['tf.concat_2[0][0]']
#
#  tf.concat_3 (TFOpLambda)       (None, 32, 32, 12)   0           ['conv2d_2[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 4)    52          ['tf.concat_3[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 64)   320         ['conv2d_5[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 32, 32, 64)  3200        ['conv2d_7[0][0]']
#  onv2D)
#
#  tf.concat_4 (TFOpLambda)       (None, 32, 32, 128)  0           ['conv2d_7[0][0]',
#                                                                   'depthwise_conv2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 64)   8256        ['tf.concat_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 64)   256         ['rescaling_1[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 32, 32, 64)  0           ['conv2d_6[0][0]']
#  oling2D)
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 32, 32, 64)  640         ['conv2d_8[0][0]']
#  onv2D)
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 64)   0           ['conv2d_8[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 32, 32, 64)  0           ['conv2d_8[0][0]']
#  oling2D)
#
#  tf.concat_5 (TFOpLambda)       (None, 32, 32, 128)  0           ['average_pooling2d_1[0][0]',
#                                                                   'depthwise_conv2d_4[0][0]']
#
#  tf.concat_6 (TFOpLambda)       (None, 32, 32, 128)  0           ['max_pooling2d[0][0]',
#                                                                   'average_pooling2d_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 64)   8256        ['tf.concat_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   8256        ['tf.concat_6[0][0]']
#
#  tf.concat_7 (TFOpLambda)       (None, 32, 32, 192)  0           ['conv2d_8[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 64)   12352       ['tf.concat_7[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  640         ['conv2d_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  8320        ['conv2d_11[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 32, 32, 128)  0          ['conv2d_12[0][0]']
#  oling2D)
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 32, 32, 128)  3328       ['conv2d_13[0][0]']
#  onv2D)
#
#  tf.concat_8 (TFOpLambda)       (None, 32, 32, 256)  0           ['average_pooling2d_3[0][0]',
#                                                                   'depthwise_conv2d_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 128)  32896       ['tf.concat_8[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 32, 32, 128)  3328       ['conv2d_14[0][0]']
#  onv2D)
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 32, 32, 128)  3328       ['conv2d_14[0][0]']
#  onv2D)
#
#  tf.concat_9 (TFOpLambda)       (None, 32, 32, 256)  0           ['conv2d_13[0][0]',
#                                                                   'depthwise_conv2d_6[0][0]']
#
#  tf.concat_10 (TFOpLambda)      (None, 32, 32, 256)  0           ['depthwise_conv2d_7[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 128)  32896       ['tf.concat_9[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 128)  32896       ['tf.concat_10[0][0]']
#
#  tf.concat_11 (TFOpLambda)      (None, 32, 32, 384)  0           ['conv2d_14[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 128)  49280       ['tf.concat_11[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 512)  66048       ['conv2d_17[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 32, 32, 512)  25600      ['conv2d_19[0][0]']
#  onv2D)
#
#  tf.concat_12 (TFOpLambda)      (None, 32, 32, 1024  0           ['conv2d_19[0][0]',
#                                 )                                 'depthwise_conv2d_8[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 512)  524800      ['tf.concat_12[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 512)  33280       ['conv2d_11[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 32, 32, 512)  0          ['conv2d_18[0][0]']
#  oling2D)
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 32, 32, 512)  5120       ['conv2d_20[0][0]']
#  onv2D)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 512)  0          ['conv2d_20[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 32, 32, 512)  0          ['conv2d_20[0][0]']
#  oling2D)
#
#  tf.concat_13 (TFOpLambda)      (None, 32, 32, 1024  0           ['average_pooling2d_4[0][0]',
#                                 )                                 'depthwise_conv2d_9[0][0]']
#
#  tf.concat_14 (TFOpLambda)      (None, 32, 32, 1024  0           ['max_pooling2d_1[0][0]',
#                                 )                                 'average_pooling2d_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 512)  524800      ['tf.concat_13[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 512)  524800      ['tf.concat_14[0][0]']
#
#  tf.concat_15 (TFOpLambda)      (None, 32, 32, 1536  0           ['conv2d_20[0][0]',
#                                 )                                 'conv2d_21[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 512)  786944      ['tf.concat_15[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 1024  132096      ['conv2d_17[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 1024  525312      ['conv2d_23[0][0]']
#                                 )
#
#  average_pooling2d_6 (AveragePo  (None, 32, 32, 1024  0          ['conv2d_24[0][0]']
#  oling2D)                       )
#
#  depthwise_conv2d_10 (Depthwise  (None, 32, 32, 1024  26624      ['conv2d_25[0][0]']
#  Conv2D)                        )
#
#  tf.concat_16 (TFOpLambda)      (None, 32, 32, 2048  0           ['average_pooling2d_6[0][0]',
#                                 )                                 'depthwise_conv2d_10[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 1024  2098176     ['tf.concat_16[0][0]']
#                                 )
#
#  depthwise_conv2d_11 (Depthwise  (None, 32, 32, 1024  26624      ['conv2d_26[0][0]']
#  Conv2D)                        )
#
#  depthwise_conv2d_12 (Depthwise  (None, 32, 32, 1024  26624      ['conv2d_26[0][0]']
#  Conv2D)                        )
#
#  tf.concat_17 (TFOpLambda)      (None, 32, 32, 2048  0           ['conv2d_25[0][0]',
#                                 )                                 'depthwise_conv2d_11[0][0]']
#
#  tf.concat_18 (TFOpLambda)      (None, 32, 32, 2048  0           ['depthwise_conv2d_12[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 1024  2098176     ['tf.concat_17[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 1024  2098176     ['tf.concat_18[0][0]']
#                                 )
#
#  tf.concat_19 (TFOpLambda)      (None, 32, 32, 3072  0           ['conv2d_26[0][0]',
#                                 )                                 'conv2d_27[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 1024  3146752     ['tf.concat_19[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['conv2d_29[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           10250       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 12,889,154
# Trainable params: 12,889,154
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Architecture Search

# %%
class Controller():
    def __init__(self, params, child_params, search_space):
        self.population_size = params['population_size']
        self.population = deque(maxlen=self.population_size)
        self.histories = []
        self.sample_size = params['sample_size']
        self.best_accuracies = []
        self.best_children = []
        self.params = params
        self.child_params = child_params
        self.search_space = search_space
        self.mutation_strategies = MutationStrategies(search_space)
        self.mutation_strategy = self.mutation_strategies.get(
            self.params['mutation_strategy']
        )
        self.merge_strategies = MergeStrategies(
            search_space,
            self.mutation_strategies.get('gene_shuffle')
        )
        self.merge_strategy = self.merge_strategies.get(
            self.params['merge_strategy']
        )
        self.parent_selection_strategies = ParentSelectionStrategies()
        self.parent_selection_strategy = self.parent_selection_strategies.get(
            self.params['parent_selection_strategy']
        )
    
    def random_child_config(self):
        return np.array(list(map(
            lambda _: self.search_space.random(),
            range(self.child_params['cells'])
        )))

    def create_random_child(self):
        config = self.random_child_config()
        child = Child(config, self.child_params, train=False)
        return child

    def initialize_population(self):
        """
        It creates children as specified through the size parameter.
        Each child is trained and their history is stored.
        It should be called only once.

        Arguments:
            size: The size of the population.
        """
        def work_fn():
            self.population.extend(map(
                lambda _: self.create_random_child(),
                range(self.sample_size)
            ))
            self.histories += self.population
        
        work_fn() if not self.population else None
    
    def mutate(self, config):
        def mutate_cell(cell_config):
            return reduce(
                lambda c,_: self.mutation_strategy(c),
                range(self.params['max_mutations']),
                cell_config
            )

        mutated_config = np.array(list(
            map(mutate_cell, config.copy())
        ))

        return mutated_config
    
    def choose_parents(self):
        p_sample = sample(range(len(self.population)), self.sample_size)
        sample_accuracies = list(map(
            lambda idx: self.population[idx].accuracy,
            p_sample
        ))
        ordered_sample = np.argsort(sample_accuracies)
        parent_ids = self.parent_selection_strategy(len(p_sample))
        sample_ids = list(map(
            lambda p_id: ordered_sample[p_id],
            parent_ids
        ))
        population_ids = list(map(lambda s_id: p_sample[s_id], sample_ids))
        parents = list(map(lambda p_id: self.population[p_id], population_ids))

        return parents
    
    def record_best(self):
        # Record the best accuracies
        population_accuracies = list(map(
            lambda item: item.accuracy,
            self.population
        ))

        self.best_accuracies.append(max(population_accuracies))
        self.best_children.append(np.argmax(population_accuracies))
    
    def update_population(self, child):
        if len(self.population) == self.population_size:
            print('Removal Candidate: {}\n Accuracy: {:1.5f}'.format(
                self.population[0].config,
                self.population[0].accuracy
            ))

        self.population.append(child)
    
    def reproduce(self, *parents):
        first, second = parents
        merged_config = self.merge_strategy(
            first.config,
            second.config
        )
        mutated_config = self.mutate(merged_config)
        child = Child(mutated_config, self.child_params, train=False)

        return child
    
    """How to send sorted configs to parent selection strategy?"""
    def run_cycle(self):
        # Pick parents
        first, second = self.choose_parents()
        print('First Parent: {}\n Accuracy: {:1.5f}'.format(
            first.config,
            first.accuracy
        ))
        print('Second Parent: {}\n Accuracy: {:1.5f}'.format(
            second.config,
            second.accuracy
        ))

        # Reproduce
        mutated_child = self.reproduce(first, second)

        # Update population
        self.update_population(mutated_child)

        # Record best children
        self.record_best()

        # Add the mutated child to the histories
        self.histories.append(mutated_child)

controller = Controller(CONTROLLER_PARAMS, CHILD_PARAMS, search_space)
controller.initialize_population()

for episode in range(CONTROLLER_PARAMS['episodes']):
    print('Cycle: ', episode)
    controller.run_cycle()
# Out:
# Block Id: 0 2 0
# Block Config: [0 1 1 3 0] 2
# Block Id: 1 2 1
# Block Config: [1 2 5 5 0] 3
# Block Id: 2 2 2
# Block Config: [2 2 4 4 0] 4
# Block Id: 0 2 0
# Block Config: [1 1 3 4 0] 2
# Block Id: 1 2 1
# Block Config: [1 2 5 4 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 3 5 1] 4
# Block Id: 0 2 0
# Block Config: [0 1 1 3 0] 2
# Block Id: 1 2 1
# Block Config: [1 2 5 5 0] 3
# Block Id: 2 2 2
# Block Config: [2 2 4 4 0] 4
# Block Id: 0 2 0
# Block Config: [1 1 3 4 0] 2
# Block Id: 1 2 1
# Block Config: [1 2 5 4 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 3 5 1] 4
# Block Id: 0 2 0
# Block Config: [0 1 1 3 0] 2
# Block Id: 1 2 1
# Block Config: [1 2 5 5 0] 3
# Block Id: 2 2 2
# Block Config: [2 2 4 4 0] 4
# Child: [[[0 1 1 3 0]
#   [1 2 5 5 0]
#   [2 2 4 4 0]]
#
#  [[1 1 3 4 0]
#   [1 2 5 4 1]
#   [1 2 3 5 1]]]
#  Accuracy: 0.0000
# Block Id: 0 2 0
# Block Config: [1 0 1 1 1] 2
# Block Id: 1 2 1
# Block Config: [1 2 0 1 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 4 2 0] 4
# Block Id: 0 2 0
# Block Config: [1 1 5 0 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 0 4 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 4 0 0] 4
# Block Id: 0 2 0
# Block Config: [1 0 1 1 1] 2
# Block Id: 1 2 1
# Block Config: [1 2 0 1 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 4 2 0] 4
# Block Id: 0 2 0
# Block Config: [1 1 5 0 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 0 4 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 4 0 0] 4
# Block Id: 0 2 0
# Block Config: [1 0 1 1 1] 2
# Block Id: 1 2 1
# Block Config: [1 2 0 1 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 4 2 0] 4
# Child: [[[1 0 1 1 1]
#   [1 2 0 1 1]
#   [0 2 4 2 0]]
#
#  [[1 1 5 0 1]
#   [0 2 0 4 1]
#   [1 2 4 0 0]]]
#  Accuracy: 0.0000
# Block Id: 0 2 0
# Block Config: [0 1 0 1 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 1 0 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 3 5 1] 4
# Block Id: 0 2 0
# Block Config: [1 0 4 4 1] 2
# Block Id: 1 2 1
# Block Config: [2 2 3 4 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 2 0 0] 4
# Block Id: 0 2 0
# Block Config: [0 1 0 1 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 1 0 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 3 5 1] 4
# Block Id: 0 2 0
# Block Config: [1 0 4 4 1] 2
# Block Id: 1 2 1
# Block Config: [2 2 3 4 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 2 0 0] 4
# Block Id: 0 2 0
# Block Config: [0 1 0 1 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 1 0 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 3 5 1] 4
# Child: [[[0 1 0 1 1]
#   [0 2 1 0 1]
#   [0 2 3 5 1]]
#
#  [[1 0 4 4 1]
#   [2 2 3 4 1]
#   [0 2 2 0 0]]]
#  Accuracy: 0.0000
# Block Id: 0 2 0
# Block Config: [1 1 3 2 0] 2
# Block Id: 1 2 1
# Block Config: [2 2 3 0 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 0 3 0] 4
# Block Id: 0 2 0
# Block Config: [0 0 5 2 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 2 5 1] 3
# Block Id: 2 2 2
# Block Config: [2 2 4 3 1] 4
# Block Id: 0 2 0
# Block Config: [1 1 3 2 0] 2
# Block Id: 1 2 1
# Block Config: [2 2 3 0 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 0 3 0] 4
# Block Id: 0 2 0
# Block Config: [0 0 5 2 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 2 5 1] 3
# Block Id: 2 2 2
# Block Config: [2 2 4 3 1] 4
# Block Id: 0 2 0
# Block Config: [1 1 3 2 0] 2
# Block Id: 1 2 1
# Block Config: [2 2 3 0 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 0 3 0] 4
# Child: [[[1 1 3 2 0]
#   [2 2 3 0 1]
#   [0 2 0 3 0]]
#
#  [[0 0 5 2 1]
#   [0 2 2 5 1]
#   [2 2 4 3 1]]]
#  Accuracy: 0.0000
# Cycle:  0
# First Parent: [[[1 1 3 2 0]
#   [2 2 3 0 1]
#   [0 2 0 3 0]]
#
#  [[0 0 5 2 1]
#   [0 2 2 5 1]
#   [2 2 4 3 1]]]
#  Accuracy: 0.00000
# Second Parent: [[[1 0 1 1 1]
#   [1 2 0 1 1]
#   [0 2 4 2 0]]
#
#  [[1 1 5 0 1]
#   [0 2 0 4 1]
#   [1 2 4 0 0]]]
#  Accuracy: 0.00000
# Point Mutation
# ===============
#  (0, 0) 1
# [['1' '' '' '' '']
#  ['' '' '' '' '']
#  ['' '' '' '' '']]
# [[ True  True  True  True  True]
#  [ True  True  True  True  True]
#  [ True  True  True  True  True]]
# Point Mutation
# ===============
#  (2, 2) 2
# [['' '' '' '' '']
#  ['' '' '' '' '']
#  ['' '' '2' '' '']]
# [[ True  True  True  True  True]
#  [ True  True  True  True  True]
#  [ True  True False  True  True]]
# Point Mutation
# ===============
#  (0, 1) 1
# [['' '1' '' '' '']
#  ['' '' '' '' '']
#  ['' '' '' '' '']]
# [[ True False  True  True  True]
#  [ True  True  True  True  True]
#  [ True  True  True  True  True]]
# Point Mutation
# ===============
#  (2, 3) 0
# [['' '' '' '' '']
#  ['' '' '' '' '']
#  ['' '' '' '0' '']]
# [[ True  True  True  True  True]
#  [ True  True  True  True  True]
#  [ True  True  True  True  True]]
# Block Id: 0 2 0
# Block Config: [1 1 3 2 0] 2
# Block Id: 1 2 1
# Block Config: [2 2 3 0 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 2 2 0] 4
# Block Id: 0 2 0
# Block Config: [0 1 5 2 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 2 5 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 4 0 0] 4
# Block Id: 0 2 0
# Block Config: [1 1 3 2 0] 2
# Block Id: 1 2 1
# Block Config: [2 2 3 0 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 2 2 0] 4
# Block Id: 0 2 0
# Block Config: [0 1 5 2 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 2 5 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 4 0 0] 4
# Block Id: 0 2 0
# Block Config: [1 1 3 2 0] 2
# Block Id: 1 2 1
# Block Config: [2 2 3 0 1] 3
# Block Id: 2 2 2
# Block Config: [0 2 2 2 0] 4
# Child: [[[1 1 3 2 0]
#   [2 2 3 0 1]
#   [0 2 2 2 0]]
#
#  [[0 1 5 2 1]
#   [0 2 2 5 1]
#   [1 2 4 0 0]]]
#  Accuracy: 0.0000
# Cycle:  1
# First Parent: [[[0 1 0 1 1]
#   [0 2 1 0 1]
#   [0 2 3 5 1]]
#
#  [[1 0 4 4 1]
#   [2 2 3 4 1]
#   [0 2 2 0 0]]]
#  Accuracy: 0.00000
# Second Parent: [[[1 1 3 2 0]
#   [2 2 3 0 1]
#   [0 2 2 2 0]]
#
#  [[0 1 5 2 1]
#   [0 2 2 5 1]
#   [1 2 4 0 0]]]
#  Accuracy: 0.00000
# Point Mutation
# ===============
#  (1, 1) 2
# [['' '' '' '' '']
#  ['' '2' '' '' '']
#  ['' '' '' '' '']]
# [[ True  True  True  True  True]
#  [ True  True  True  True  True]
#  [ True  True  True  True  True]]
# Point Mutation
# ===============
#  (2, 0) 1
# [['' '' '' '' '']
#  ['' '' '' '' '']
#  ['1' '' '' '' '']]
# [[ True  True  True  True  True]
#  [ True  True  True  True  True]
#  [False  True  True  True  True]]
# Point Mutation
# ===============
#  (0, 1) 0
# [['' '0' '' '' '']
#  ['' '' '' '' '']
#  ['' '' '' '' '']]
# [[ True  True  True  True  True]
#  [ True  True  True  True  True]
#  [ True  True  True  True  True]]
# Point Mutation
# ===============
#  (0, 0) 0
# [['0' '' '' '' '']
#  ['' '' '' '' '']
#  ['' '' '' '' '']]
# [[False  True  True  True  True]
#  [ True  True  True  True  True]
#  [ True  True  True  True  True]]
# Block Id: 0 2 0
# Block Config: [0 1 0 1 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 1 0 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 2 2 0] 4
# Block Id: 0 2 0
# Block Config: [0 0 4 4 1] 2
# Block Id: 1 2 1
# Block Config: [2 2 3 4 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 4 0 0] 4
# Block Id: 0 2 0
# Block Config: [0 1 0 1 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 1 0 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 2 2 0] 4
# Block Id: 0 2 0
# Block Config: [0 0 4 4 1] 2
# Block Id: 1 2 1
# Block Config: [2 2 3 4 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 4 0 0] 4
# Block Id: 0 2 0
# Block Config: [0 1 0 1 1] 2
# Block Id: 1 2 1
# Block Config: [0 2 1 0 1] 3
# Block Id: 2 2 2
# Block Config: [1 2 2 2 0] 4
# Child: [[[0 1 0 1 1]
#   [0 2 1 0 1]
#   [1 2 2 2 0]]
#
#  [[0 0 4 4 1]
#   [2 2 3 4 1]
#   [1 2 4 0 0]]]
#  Accuracy: 0.0000

# %%
accuracies = list(map(lambda child: child.accuracy, controller.histories))
accuracies_df = pd.DataFrame(accuracies)
rolling_accuracies = accuracies_df.rolling(len(controller.population)).mean()[0].tolist()

plt.plot(accuracies, label='Accuracy')
axes = plt.plot(rolling_accuracies, label='Rolling Accuracy')
plt.xlabel('Trials')
plt.legend()
plt.title('Evolution NAS')
plt.gca().xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

# %%
def plot(data, ax, label='', highlight=5, intx=True, inty=False):
    sorted_data = sorted(data)
    sorted_indices = np.argsort(data)

    ax.plot(data, label=label)
    intx and ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
    inty and ax.yaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    ax.xaxis.grid()
    ax.yaxis.grid()
    ax.legend()

fig, axes = plt.subplots(1, 2)
fig.suptitle('Best Performers in a Cycle')

ax_acc, ax_child = axes
plot(controller.best_accuracies, ax_acc, label='Best Accuracy')
plot(controller.best_children, ax_child, label='Best Child', inty=True)

print('[{}]'.format(', '.join(f'{q:.4f}' for q in controller.best_accuracies)))
print(controller.best_children)
# Out:
# [0.0000, 0.0000]
# [0, 0]

# %% [markdown]
# ## Cell Visualization

# %% [markdown]
# ### Single Layer Visual Cell

# %%
class VisualCell(object):
    def __init__(self, state_space, config) -> None:
        self.state_space = state_space
        self.config = config
        self.palette = seaborn.color_palette("mako_r", 7).as_hex()

        self.G = nx.DiGraph()
        self.labels = {
            'input 0': 'input 0',
            'input 1': 'input 1',
            'concat_blocks': 'concat'
        }
        self.colors = {
            'input 0': self.palette[0],
            'input 1': self.palette[1],
            'concat_blocks': self.palette[5]
        }

        # Add input nodes
        for input_state in self.state_space[0]['values']:
            self.G.add_node(
                self.input_label(input_state),
                layer=0
            )

        # Add primary and combination nodes for blocks
        for nid in range(3*CHILD_PARAMS['blocks']):
            self.G.add_node(
                nid,
                layer=self.get_layer_id(nid)
            )

        # Add block combination node
        self.G.add_node('concat_blocks', layer=3)

    def input_label(self, idx) -> str:
        return 'input {}'.format(idx)

    def primary_op_label(self, idx) -> str:
        return self.state_space[1]['values'][idx].replace('_', '\n')

    def combination_op_label(self, idx) -> str:
        return self.state_space[2]['values'][idx]

    def get_node_id(self, bid, item):
        return bid*3 + item

    def get_layer_id(self, nid) -> int:
        return 2 if (nid+1)%3 ==0 else 1

    def compose_block(self, bid, block):
        input_0, input_1, op_1, op_2, comb = block
        nid_op_0, nid_op_1 = self.get_node_id(bid, 0), self.get_node_id(bid, 1)
        nid_comb = self.get_node_id(bid, 2)

        # Add primary styles
        # self.labels[nid_op_0] = self.state_space[1]['values'][op_1]
        self.labels[nid_op_0] = self.primary_op_label(op_1)
        self.labels[nid_op_1] = self.primary_op_label(op_2)

        self.colors[nid_op_0] = self.palette[2]
        self.colors[nid_op_1] = self.palette[3]

        # Add combination styles
        self.labels[nid_comb] = self.state_space[2]['values'][comb]
        self.colors[nid_comb] = self.palette[4]

        # Add incoming edges for primary operations
        self.G.add_edge(
            self.input_label(input_0),
            self.get_node_id(bid, 0),
            color=self.palette[0]
        )
        self.G.add_edge(
            self.input_label(input_1),
            self.get_node_id(bid, 1),
            color=self.palette[1]
        )

        # Add incoming edges for the combination operation
        self.G.add_edge(
            self.get_node_id(bid, 0),
            self.get_node_id(bid, 2),
            color=self.palette[2]
        )
        self.G.add_edge(
            self.get_node_id(bid, 1),
            self.get_node_id(bid, 2),
            color=self.palette[3]
        )

        # Add outgoing edges for the combination operation
        self.G.add_edge(
            self.get_node_id(bid, 2),
            'concat_blocks',
            color=self.palette[4]
        )
    
    def draw(self, ax):
        # Process cell
        for bid in range(self.config.shape[0]):
            self.compose_block(bid, self.config[bid])

        # Create a multipartite layout to arrange inputs, primary
        # and combination operations in their respective layers.
        pos = nx.multipartite_layout(
            self.G,
            subset_key='layer',
            align='horizontal'
        )

        # Configure edge colors
        edge_colors = nx.get_edge_attributes(self.G,'color').values()

        # Draw cell structure
        nx.draw(
            self.G,
            pos=pos,
            node_color=list(map(lambda l: self.colors[l], self.G.nodes)),
            edge_color=edge_colors,
            node_size=list(map(lambda _:500, self.G.nodes)),
            ax=ax,
        )

        # Label cell operations
        nx.draw_networkx_labels(
            self.G,
            pos=pos,
            labels=self.labels,
            font_size=5,
            font_color=self.palette[6],
            ax=ax
        )

# def visualize_cell(ax, config, title='Cell'):
#     ax.set_title(title)

#     visual = VisualCell(STATE_SPACE, config)
#     visual.draw(ax)

# accuracies = list(map(lambda child: child.accuracy, controller.histories))
# num_selected_trials = 3
# visual_size = CHILD_PARAMS['blocks']
# best_configs = list(map(
#     lambda idx: (controller.histories[idx].config, controller.histories[idx].accuracy),
#     np.argsort(accuracies)[-num_selected_trials:][::-1]
# ))

# for idx, (config, accuracy) in enumerate(best_configs):
#     fig, axes = plt.subplots(1, 2, figsize=(2*visual_size, visual_size))
#     visualize_cell(axes[0], config[0], 'Normal Cell')
#     visualize_cell(axes[1], config[1], 'Reduction Cell')
#     fig.suptitle('Accuracy: {:.2f}%'.format(accuracy*100))

# best_configs

# %% [markdown]
# ### Two Layer Visual Cell

# %%
class TwoLayerVisualCell(object):
    def __init__(self, description) -> None:
        """
        We add 1 level each for inputs and outputs
        Each block gets 2 levels, one for primitive operations and
        another for combination operations. Two layer cells have
        blocks in two layers.
        """
        self.description = description
        self.levels = 1 + 2*2 + 1
        self.palette = seaborn.color_palette("mako_r", self.levels+5).as_hex()
        self.layer_0_blocks = self.description.shape[0]//2

        # Input and output nodes
        self.input_nodes = ['input 0', 'input 1']
        self.output_nodes = ['output']

        # Node graph
        self.G = nx.DiGraph()
        self.lay_nodes()


    
    def add_nodes(self, nodes, level, labels=[]):
        labels = labels or nodes
        for node, label in zip(nodes, labels):
            self.G.add_node(node, label=label, level=level, color=self.palette[level])
    
    def add_block(self, b_id, block, layer=0):
        # Block operation levels
        primitive_op_level = 1 + 2*layer
        comb_op_level = 1 + 2*layer + 1

        # Node ids
        start_id = block.shape[-1]*b_id
        primitive_0_id, primitive_1_id = start_id, start_id+1
        comb_id = 'block {}'.format(b_id)

        ######## Node Section ########
        self.add_nodes(
            [primitive_0_id, primitive_1_id],
            primitive_op_level,
            labels=list(block[2:4])
        )
        self.add_nodes([comb_id], comb_op_level, labels=[block[4]])

        ######## Edge Section ########
        self.G.add_edge(block[0], primitive_0_id)
        self.G.add_edge(block[1], primitive_1_id)
        self.G.add_edge(primitive_0_id, comb_id)
        self.G.add_edge(primitive_1_id, comb_id)
    
    def lay_nodes(self):
        block_outputs = list(map(
            lambda b_id: 'block {}'.format(b_id),
            range(self.description.shape[0])
        ))

        # Lay out input nodes
        self.add_nodes(self.input_nodes, level=0)

        # First layer blocks
        layer_0_blocks = self.description[:self.layer_0_blocks]

        # Layout the first block layer
        for b_id, block in enumerate(layer_0_blocks):
            self.add_block(b_id, block, layer=0)
        
        # Layout the second block layer
        layer_1_blocks = self.description[self.layer_0_blocks:]
        for b_id, block in enumerate(layer_1_blocks):
            self.add_block(b_id + len(layer_0_blocks), block, layer=1)

        # Lay out output nodes
        self.add_nodes(self.output_nodes, level=self.levels-1)

        # Connect block outputs to the output node
        for block in block_outputs:
            self.G.add_edge(block, 'output')

    def get_node_attributes(self, name, as_dict=True):
        if as_dict:
            attributes = dict(map(
                lambda item: (item[0], item[1][name]),
                self.G.nodes(data=True)
            ))
        else:
            attributes = list(map(
                lambda item: item[1][name],
                self.G.nodes(data=True)
            ))
        
        return attributes
    
    def draw(self, ax):
        # Create a multipartite layout to arrange inputs, primary
        # and combination operations in their respective layers.
        pos = nx.multipartite_layout(
            self.G,
            subset_key='level',
            align='horizontal'
        )

        # Node Attributes
        labels = self.get_node_attributes(name='label')
        colors = self.get_node_attributes(name='color', as_dict=False)
        node_size=list(map(lambda _:500, self.G.nodes))

        # Draw cell structure
        nx.draw(
            self.G,
            pos=pos,
            node_color=colors,
            # edge_color=edge_colors,
            node_size=node_size,
            ax=ax,
        )

        # Label nodes
        nx.draw_networkx_labels(
            self.G,
            pos=pos,
            labels=labels,
            font_size=5,
            font_color=self.palette[-1],
            ax=ax
        )

# ax = plt.subplot()
# cell_config = search_space.random()
# cell_description = search_space.decode(cell_config)
# visual = TwoLayerVisualCell(cell_description)
# visual.draw(ax)

# %% [markdown]
# ### Visualization

# %%
def visualize_cell(ax, config, title='Cell'):
    ax.set_title(title)
    cell_description = search_space.decode(config)

    visual = TwoLayerVisualCell(cell_description)
    visual.draw(ax)

accuracies = list(map(lambda child: child.accuracy, controller.histories))
num_selected_trials = 3
visual_size = CHILD_PARAMS['blocks']
best_configs = list(map(
    lambda idx: (controller.histories[idx].config, controller.histories[idx].accuracy),
    np.argsort(accuracies)[-num_selected_trials:][::-1]
))

for idx, (config, accuracy) in enumerate(best_configs):
    fig, axes = plt.subplots(1, 2, figsize=(2*visual_size, visual_size))
    visualize_cell(axes[0], config[0], 'Normal Cell')
    visualize_cell(axes[1], config[1], 'Reduction Cell')
    fig.suptitle('Accuracy: {:.2f}%'.format(accuracy*100))

best_configs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [47], line 8
#       5     visual = TwoLayerVisualCell(cell_description)
#       6     visual.draw(ax)
# ----> 8 accuracies = list(map(lambda child: child.accuracy, controller.histories))
#       9 num_selected_trials = 3
#      10 visual_size = CHILD_PARAMS['blocks']
#
# NameError: name 'controller' is not defined
